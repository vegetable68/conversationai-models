# %% [markdown]
# # Attention Based Classification Codelab
#
# **Recommended time: 30 minutes**
#
# **Contributors: nthain, you?**
#
#
# This codelab provides an introduction to building text classification models in tensorflow that use attention to provide insight into how classification decisions are being made. We will build our tensorflow graph following the Embed - Encode - Attend - Predict paradigm introduced by Matthew Honnibal. For more information about this approach, you can refer to:
#
# Slides: https://goo.gl/BYT7au
#
# Video: https://youtu.be/pzOzmxCR37I
#
#
# Figure 1 below provides a representation of the full tensorflow graph we will build in this codelab. In this codelab we will implement each piece of this model graph in a seperate function. The whole model will then simply be calling all of these functions in turn.
#
#
# ![Figure 1](img/entire_model.png "Figure 1")

# %% [markdown]
# ### Imports

# %%
# %load_ext autoreload
# %autoreload 2

from __future__ import absolute_import
from __future__ import division
from __future__ import print_function


import pandas as pd
import tensorflow as tf
import numpy as np
import time
import os
from sklearn import metrics
from visualize_attention import attentionDisplay
from process_figshare import process_figshare

# %% [markdown]
# ## Load & Explore Data

# %% [markdown]
# Let's begin by loading the data, which is available from [Figshare](https://figshare.com/articles/Wikipedia_Talk_Labels_Toxicity/4563973), into a pandas Dataframe. From the link, download toxicity_annotations.tsv and toxicity_annotated_comments.tsv to the data/ directory. We then run the prepare_figshare function to clean the data and split it into a train, dev, and test set.

# %%
process_figshare()
# Out:
# Processed files already exist.

# %%
SPLITS = ['train', 'dev', 'test']

wiki = {}
for split in SPLITS:
    wiki[split] = pd.read_csv('data/wiki_%s.csv' % split)

# %% [markdown]
# We display the top few rows of the dataframe to see what we're dealing with. The key columns are 'comment' which contains the text of a comment from a Wikipedia talk page and 'toxicity' which contains the fraction of annotators who found this comment to be toxic. More information about the other fields and how this data was collected can be found on [this wiki](https://meta.wikimedia.org/wiki/Research:Detox/Data_Release) and [research paper](https://arxiv.org/abs/1610.08914).

# %%
wiki['train'].head(5)
# Out:
#     rev_id  toxicity                                            comment  year  \
# 0   2232.0       0.1  This: :One can make an analogy in mathematical...  2002
# 1   4216.0       0.0  `  :Clarification for you  (and Zundark's righ...  2002
# 2  26547.0       0.0  `This is such a fun entry.   Devotchka  I once...  2002
# 3  37330.0       0.3  `   I fixed the link; I also removed ``homeopa...  2002
# 4  37346.0       0.1  `If they are ``indisputable`` then why does th...  2002
#
#    logged_in       ns  sample  split  is_toxic
# 0       True  article  random  train     False
# 1       True     user  random  train     False
# 2       True  article  random  train     False
# 3       True  article  random  train     False
# 4       True  article  random  train     False

# %% [markdown]
# **TODO(nthain): Visualize the data (histogram)**

# %% [markdown]
# ### Hyperparameters

# %% [markdown]
# **TODO(nthain): Move hyperparameters to a dict and put in an explanation**

# %%
MAX_DOCUMENT_LENGTH = 200
EMBEDDING_SIZE = 300
RNN_CELL_SIZE = 128
BATCH_SIZE = 256
ATTENTION_SIZE = 32
ATTENTION_DEPTH = 2

# %%
#n_words = 0
MAX_LABEL = 2
WORDS_FEATURE = 'words'
NUM_STEPS = 300

# %% [markdown]
# ### Step 0: Text Preprocessing

# %% [markdown]
# Before we can build a neural network on comment strings, we first have to complete a number of preprocessing steps. In particular, it is important that we "tokenize" the string, splitting it into an array of tokens. In our case, each token will be a word in our sentence and they will be seperated by spaces and punctuation. Many alternative tokenizers exist, some of which use characters as tokens, and others which include punctuation, emojis, or even cleverly handle misspellings.
#
# Once we've tokenized the sentences, each word will be replaced with an integer representative. This will make the embedding (Step 1) much easier.
#
# Happily the tensorflow function VocabularyProcessor takes care of both the tokenization and integer mapping. We only have to give it the max_document_length argument which will determine the length of the output arrays. If sentences are shorter than this length, they will be padded and if they are longer, they will be trimmed.

# %%
# Initialize the vocabulary processor
vocab_processor = tf.contrib.learn.preprocessing.VocabularyProcessor(MAX_DOCUMENT_LENGTH)

def process_inputs(vocab_processor, df, train_label = 'train', test_label = 'test'):
    
    # For simplicity, we call our features x and our outputs y
    x_train = df['train'].comment
    y_train = df['train'].is_toxic
    x_test = df['test'].comment
    y_test = df['test'].is_toxic

    # Train the vocab_processor from the training set
    x_train = vocab_processor.fit_transform(x_train)
    # Transform our test set with the vocabulary processor
    x_test = vocab_processor.transform(x_test)

    # We need these to be np.arrays instead of generators
    x_train = np.array(list(x_train))
    x_test = np.array(list(x_test))
    y_train = np.array(y_train).astype(int)
    y_test = np.array(y_test).astype(int)

    n_words = len(vocab_processor.vocabulary_)
    print('Total words: %d' % n_words)

    # Return the transformed data and the number of words
    return x_train, y_train, x_test, y_test, n_words

x_train, y_train, x_test, y_test, n_words = process_inputs(vocab_processor, wiki)
# Out:
# Total words: 196427

# %% [markdown]
# ### Step 1: Embed

# %% [markdown]
# Neural networks at their core are a composition of operators from linear algebra and non-linear activation functions. In order to perform these computations on our input sentences, we must first embed them as a vector of numbers. There are two main approaches to perform this embedding:
#
#
# 1.   **Pre-trained:** It is often beneficial to initialize our embedding matrix using pre-trained embeddings like [Word2Vec](??) or [GloVe](??). These embeddings are trained on a huge corpus of text with a general purpose problem so that they incorporate syntactic and semantic properties of the words being embedded and are amenable to transfer learning on new problems. Once initialized, you can optionally train them further for your specific problem by allowing the embedding matrix in the graph to be a trainable variable in our tensorflow graph.
# 2.   **Random:** Alternatively, embeddings can be "trained from scratch" by initializing the embedding matrix randomly and then training it like any other parameter in the tensorflow graph.

# %% [markdown]
# In this notebook, we will be using a random initialization. To perform this embedding we use the embed_sequence function from the layers package. This will take our input features, which are the arrays of integers we produced in Step 0, and will randomly initialize a matrix to embed them into. The parameters of this matrix will then be trained with the rest of the graph.
#
# **TODO(nthain): Add pre-trained initialization**

# %%
def embed(features):
    word_vectors = tf.contrib.layers.embed_sequence(
        features[WORDS_FEATURE], vocab_size=n_words, embed_dim=EMBEDDING_SIZE)
    
    return word_vectors

# %% [markdown]
# ### Step 2: Encode

# %% [markdown]
# A recurrent neural network is a deep learning architecture that is useful for encoding sequential information like sentences. They are built around a single cell which contains one of several standard neural network architectures (e.g. simple RNN, GRU, or LSTM). We will not focus on the details of the architectures, but at each point in time the cell takes in two inputs and produces two outputs. The inputs are the input token for that step in the sequence and some state from the previous steps in the sequence. The outputs produced are the encoded vectors for the current sequence step and a state to pass on to the next step of the sequence.
#
# Figure 2 shows what this looks like for an unrolled RNN. Each cell (represented by a green square) has two input arrows and two output arrrows. Note that all of the green squares represent the same cell and share parameters. One major advantage of this cell replication is that, at inference time, it allows us to deal with arbitrary length input and not be restricted by the input sizes of our training set.
#
# For our model, we will use a bi-directional RNN. This is simply the concatentation of two RNNs, one which processes the sequence from left to right (the "forward" RNN) and one which process from right to left (the "backward" RNN). By using both directions, we get a stronger encoding as each word can be encoded using the context of its neighbors on boths sides rather than just a single side.  For our cells, we use gated recurrent units (GRUs).
#
# ![Figure 2](img/figure_2.png "Figure 2")

# %%
def encode(word_vectors):
  # Create a Gated Recurrent Unit cell with hidden size of RNN_SIZE.
  # Since the forward and backward RNNs will have different parameters, we instantiate two seperate GRUS.
  with tf.variable_scope('forward'):
    rnn_fw_cell = tf.contrib.rnn.GRUCell(RNN_CELL_SIZE)
  with tf.variable_scope('backward'):
    rnn_bw_cell = tf.contrib.rnn.GRUCell(RNN_CELL_SIZE)

  # Create an unrolled Bi-Directional Recurrent Neural Networks to length of
  # MAX_DOCUMENT_LENGTH and passes word_list as inputs for each unit.
  outputs, _ = tf.nn.bidirectional_dynamic_rnn(rnn_fw_cell, rnn_bw_cell, word_vectors, dtype=tf.float32, time_major=False)
  
  return outputs

# %% [markdown]
# ### Step 3: Attend

# %% [markdown]
# There are a number of ways to use the encoded states of a recurrent neural network for prediction. One traditional approach is to simply use the final encoded state of the network, as seen in Figure 2. However, this could lose some useful information encoded in the previous steps of the sequence. In order to keep that information, one could instead use an average of the encoded states outputted by the RNN. There is not reason to believe, though, that all of the encoded states of the RNN are equally valuable. Thus, we arrive at the idea of using a weighted sum of these encoded states to make our prediction.
#
# We will call the weights of this weighted sum "attention weights" as we will see below that they correspond to how important our model thinks each token of the sequence is in making a prediction decision. We compute these attention weights simply by building a small fully connected neural network on top of each encoded state. This network will have a single unit final layer which will correspond to the attention weight we will assign. As for RNNs, the parameters of this network will be the same for each step of the sequence, allowing us to accomodate variable length inputs. Figure 3 shows us what the graph would look like if we applied attention to a uni-directional RNN.
#
# ![Figure 3](img/figure_3.png "Figure 3")

# %%
def attend(inputs, attention_size, attention_depth):
  
  inputs = tf.concat(inputs, axis = 2)
  
  inputs_shape = inputs.shape
  sequence_length = inputs_shape[1].value
  final_layer_size = inputs_shape[2].value
  
  x = tf.reshape(inputs, [-1, final_layer_size])
  for _ in range(attention_depth-1):
    x = tf.layers.dense(x, attention_size, activation = tf.nn.relu)
  x = tf.layers.dense(x, 1, activation = None)
  logits = tf.reshape(x, [-1, sequence_length, 1])
  alphas = tf.nn.softmax(logits, dim = 1)
  
  output = tf.reduce_sum(inputs * alphas, 1)

  return output, alphas

# %% [markdown]
# ### Step 4: Predict

# %% [markdown]
# To genereate a class prediction about whether a comment is toxic or not, the final part of our tensorflow graph takes the weighted average of hidden states generated in the attention step and uses a fully connected layer with a softmax activation function to generate probability scores for each of our prediction classes. While training, the model will use the cross-entropy loss function to train its parameters.
#
# As we will use the estimator framework to train our model, we write an estimator_spec function to specify how our model is trained and what values to return during the prediction stage. We also specify the evaluation metrics of accuracy and auc, which we will use to evaluate our model in Step 7.

# %%
def estimator_spec_for_softmax_classification(
    logits, labels, mode, alphas):
  """Returns EstimatorSpec instance for softmax classification."""
  predicted_classes = tf.argmax(logits, 1)
  if mode == tf.estimator.ModeKeys.PREDICT:
    export_outputs = {
        'predict_output': tf.estimator.export.PredictOutput({
            'class': predicted_classes,
            'prob': tf.nn.softmax(logits),
            'attention': alphas
        })}
    return tf.estimator.EstimatorSpec(
        mode=mode,
        predictions={
            'class': predicted_classes,
            'prob': tf.nn.softmax(logits),
            'attention': alphas
        },
        export_outputs=export_outputs)

  onehot_labels = tf.one_hot(labels, MAX_LABEL, 1, 0)
  loss = tf.losses.softmax_cross_entropy(
      onehot_labels=onehot_labels, logits=logits)
  if mode == tf.estimator.ModeKeys.TRAIN:
    optimizer = tf.train.AdamOptimizer(learning_rate=0.01)
    train_op = optimizer.minimize(loss, global_step=tf.train.get_global_step())
    return tf.estimator.EstimatorSpec(mode, loss=loss, train_op=train_op)

  eval_metric_ops = {
      'accuracy': tf.metrics.accuracy(
          labels=labels, predictions=predicted_classes),
      'auc': tf.metrics.auc(
          labels=labels, predictions=predicted_classes),    
  }
  return tf.estimator.EstimatorSpec(
      mode=mode, loss=loss, eval_metric_ops=eval_metric_ops)

# %% [markdown]
# The predict component of our graph then just takes the output of our attention step, i.e. the weighted average of the bi-RNN hidden layers, and adds one more fully connected layer to compute the logits. These logits are fed into a our estimator_spec which uses a softmax to get the final class probabilties and a softmax_cross_entropy to build a loss function.

# %%
def predict(encoding, labels, mode, alphas):
    logits = tf.layers.dense(encoding, MAX_LABEL, activation=None)
    return estimator_spec_for_softmax_classification(
          logits=logits, labels=labels, mode=mode, alphas=alphas)

# %% [markdown]
# ### Step 5: Complete Model Architecture

# %% [markdown]
# We are now ready to put it all together. As you can see from the bi_rnn_model function below, once you have the components for embed, encode, attend, and predict, putting the whole graph together is extremely simple!

# %%
def bi_rnn_model(features, labels, mode):
  """RNN model to predict from sequence of words to a class."""

  word_vectors = embed(features)
  outputs = encode(word_vectors)
  encoding, alphas = attend(outputs, ATTENTION_SIZE, ATTENTION_DEPTH)

  return predict(encoding, labels, mode, alphas)

# %% [markdown]
# ![Figure 1](img/entire_model.png "Figure 1")

# %% [markdown]
# ### Step 6: Train Model

# %% [markdown]
# We will use the estimator framework to train our model. To define our classifier, we just provide it with the complete model graph (i.e. the bi_rnn_model function) and a directory where the models will be saved.

# %%
current_time = str(int(time.time()))
model_dir = os.path.join('checkpoints', current_time)
classifier = tf.estimator.Estimator(model_fn=bi_rnn_model, model_dir=model_dir)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_task_type': 'worker', '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fde08fcedd0>, '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_num_ps_replicas': 0, '_tf_random_seed': None, '_master': '', '_num_worker_replicas': 1, '_task_id': 0, '_log_step_count_steps': 100, '_model_dir': 'checkpoints/1521593965', '_save_summary_steps': 100}

# %% [markdown]
# The estimator framework also requires us to define an input function. This will take the input data and provide it during model training in batches. We will use the provided numpy_input_function, which takes numpy arrays as features and labels. We also specify the batch size and whether we want to shuffle the data between epochs.

# %%
# Train.
train_input_fn = tf.estimator.inputs.numpy_input_fn(
  x={WORDS_FEATURE: x_train},
  y=y_train,
  batch_size=BATCH_SIZE,
  num_epochs=None,
  shuffle=True)

# %% [markdown]
# Now, it's finally time to train our model! With estimator, this is as easy as calling the train function and specifying how long we'd like to train for.

# %%
classifier.train(input_fn=train_input_fn, steps=NUM_STEPS)
# Out:
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into checkpoints/1521593965/model.ckpt.
# INFO:tensorflow:loss = 0.69085526, step = 1
# INFO:tensorflow:global_step/sec: 2.45811
# INFO:tensorflow:loss = 0.1331726, step = 101 (40.689 sec)
# INFO:tensorflow:global_step/sec: 2.41729
# INFO:tensorflow:loss = 0.136737, step = 201 (41.365 sec)
# INFO:tensorflow:Saving checkpoints for 300 into checkpoints/1521593965/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0813523.

# %% [markdown]
# ### Step 7: Predict and Evaluate Model

# %% [markdown]
# To evaluate the function, we will use it to predict the values of examples from our test set. Again, we define a numpy_input_fn, for the test data in this case, and then have the classifier run predictions on this input function.

# %%
# Predict.
test_input_fn = tf.estimator.inputs.numpy_input_fn(
  x={WORDS_FEATURE: x_test},
  y=y_test,
  num_epochs=1,
  shuffle=False)

predictions = classifier.predict(input_fn=test_input_fn)

# %% [markdown]
# These predictions are returned to us as a generator. The code below gives an example of how we can extract the class and attention weights for each prediction.

# %%
y_predicted = []
alphas_predicted = []
for p in predictions:
    y_predicted.append(p['class'])
    alphas_predicted.append(p['attention'])
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/1521593965/model.ckpt-300

# %% [markdown]
# To evaluate our model, we can use the evaluate function provided by estimator to get the accuracy and auc scores as we defined them in our estimator_spec.

# %%
scores = classifier.evaluate(input_fn=test_input_fn)
print('Accuracy: {0:f}'.format(scores['accuracy']))
print('AUC: {0:f}'.format(scores['auc']))
# Out:
# INFO:tensorflow:Starting evaluation at 2018-03-21-01:06:51
# INFO:tensorflow:Restoring parameters from checkpoints/1521593965/model.ckpt-300
# INFO:tensorflow:Finished evaluation at 2018-03-21-01:07:21
# INFO:tensorflow:Saving dict for global step 300: accuracy = 0.95521873, auc = 0.874904, global_step = 300, loss = 0.12261739
# Accuracy: 0.955219
# AUC: 0.874904

# %% [markdown]
# ### Step 8: Display Attention

# %% [markdown]
# Now that we have a trained attention based toxicity model, let's use it to visualize how our model makes its classification decisions. We use the helpful attentionDisplay class from the visualize_attention package. Given any sentence, this class uses our trained classifier to determine whether the sentence is toxic and also returns a representation of the attention weights. In the arrays below, the more red a word is, the more weight classifier puts on encoded word. Try it out on some sentences of your own and see what patterns you can find!
#
# Note: If you are viewing this on Github, the colors in the cells won't display properly. We recommend viewing it locally or with [nbviewer](https://nbviewer.jupyter.org/github/conversationai/conversationai-models/blob/nthain-initial/attention-codelab/Attention_Model_Codelab.ipynb) to see the correct rendering of the attention weights.

# %%
display = attentionDisplay(vocab_processor, classifier)

# %%
input_string = "Fuck off, you idiot"

# %%
pred, attn = display._predict_sentence(input_string)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/1521593965/model.ckpt-300

# %%
display.display_prediction_attention("Fuck off, you idiot.")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-320eae8deb5b> in <module>()
# ----> 1 display.display_prediction_attention("Fuck off, you idiot.")
#
# AttributeError: 'function' object has no attribute 'display_prediction_attention'

# %%
display.display_prediction_attention("Thanks for your help editing this.")
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/1520622701/model.ckpt-300
# Not toxic
# <style  type="text/css" >
#     #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col0 {
#             background-color:  #ffe5e5;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col1 {
#             background-color:  #ffe4e4;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col2 {
#             background-color:  #ff6969;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col3 {
#             background-color:  #ffeaea;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col4 {
#             background-color:  #ffefef;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col5 {
#             background-color:  #fff9f9;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col6 {
#             background-color:  #fffefe;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col7 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col8 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col9 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col10 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col11 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col12 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col13 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col14 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col15 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col16 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col17 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col18 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col19 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col20 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col21 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col22 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col23 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col24 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col25 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col26 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col27 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col28 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col29 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col30 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col31 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col32 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col33 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col34 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col35 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col36 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col37 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col38 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col39 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col40 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col41 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col42 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col43 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col44 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col45 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col46 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col47 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col48 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col49 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col50 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col51 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col52 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col53 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col54 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col55 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col56 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col57 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col58 {
#             background-color:  #ffffff;
#         }    #T_1ec6d146_23cf_11e8_af05_784f439c84abrow0_col59 {
#             background-color:  #ffffff;
#         }</style>
# <table id="T_1ec6d146_23cf_11e8_af05_784f439c84ab" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >0</th>
#         <th class="col_heading level0 col1" >1</th>
#         <th class="col_heading level0 col2" >2</th>
#         <th class="col_heading level0 col3" >3</th>
#         <th class="col_heading level0 col4" >4</th>
#         <th class="col_heading level0 col5" >5</th>
#         <th class="col_heading level0 col6" >6</th>
#         <th class="col_heading level0 col7" >7</th>
#         <th class="col_heading level0 col8" >8</th>
#         <th class="col_heading level0 col9" >9</th>
#         <th class="col_heading level0 col10" >10</th>
#         <th class="col_heading level0 col11" >11</th>
#         <th class="col_heading level0 col12" >12</th>
#         <th class="col_heading level0 col13" >13</th>
#         <th class="col_heading level0 col14" >14</th>
#         <th class="col_heading level0 col15" >15</th>
#         <th class="col_heading level0 col16" >16</th>
#         <th class="col_heading level0 col17" >17</th>
#         <th class="col_heading level0 col18" >18</th>
#         <th class="col_heading level0 col19" >19</th>
#         <th class="col_heading level0 col20" >20</th>
#         <th class="col_heading level0 col21" >21</th>
#         <th class="col_heading level0 col22" >22</th>
#         <th class="col_heading level0 col23" >23</th>
#         <th class="col_heading level0 col24" >24</th>
#         <th class="col_heading level0 col25" >25</th>
#         <th class="col_heading level0 col26" >26</th>
#         <th class="col_heading level0 col27" >27</th>
#         <th class="col_heading level0 col

# %%
display.display_prediction_attention("You're such an asshole. But thanks anyway.")
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/1520622701/model.ckpt-300
# Toxic
# <style  type="text/css" >
#     #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col0 {
#             background-color:  #fff8f8;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col1 {
#             background-color:  #fff7f7;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col2 {
#             background-color:  #fff4f4;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col3 {
#             background-color:  #ff2424;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col4 {
#             background-color:  #fffefe;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col5 {
#             background-color:  #fffefe;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col6 {
#             background-color:  #fffefe;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col7 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col8 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col9 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col10 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col11 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col12 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col13 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col14 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col15 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col16 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col17 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col18 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col19 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col20 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col21 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col22 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col23 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col24 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col25 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col26 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col27 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col28 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col29 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col30 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col31 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col32 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col33 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col34 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col35 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col36 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col37 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col38 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col39 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col40 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col41 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col42 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col43 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col44 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col45 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col46 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col47 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col48 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col49 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col50 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col51 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col52 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col53 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col54 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col55 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col56 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col57 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col58 {
#             background-color:  #ffffff;
#         }    #T_1f6bf4c6_23cf_11e8_b830_784f439c84abrow0_col59 {
#             background-color:  #ffffff;
#         }</style>
# <table id="T_1f6bf4c6_23cf_11e8_b830_784f439c84ab" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >0</th>
#         <th class="col_heading level0 col1" >1</th>
#         <th class="col_heading level0 col2" >2</th>
#         <th class="col_heading level0 col3" >3</th>
#         <th class="col_heading level0 col4" >4</th>
#         <th class="col_heading level0 col5" >5</th>
#         <th class="col_heading level0 col6" >6</th>
#         <th class="col_heading level0 col7" >7</th>
#         <th class="col_heading level0 col8" >8</th>
#         <th class="col_heading level0 col9" >9</th>
#         <th class="col_heading level0 col10" >10</th>
#         <th class="col_heading level0 col11" >11</th>
#         <th class="col_heading level0 col12" >12</th>
#         <th class="col_heading level0 col13" >13</th>
#         <th class="col_heading level0 col14" >14</th>
#         <th class="col_heading level0 col15" >15</th>
#         <th class="col_heading level0 col16" >16</th>
#         <th class="col_heading level0 col17" >17</th>
#         <th class="col_heading level0 col18" >18</th>
#         <th class="col_heading level0 col19" >19</th>
#         <th class="col_heading level0 col20" >20</th>
#         <th class="col_heading level0 col21" >21</th>
#         <th class="col_heading level0 col22" >22</th>
#         <th class="col_heading level0 col23" >23</th>
#         <th class="col_heading level0 col24" >24</th>
#         <th class="col_heading level0 col25" >25</th>
#         <th class="col_heading level0 col26" >26</th>
#         <th class="col_heading level0 col27" >27</th>
#         <th class="col_heading level0 col

# %%
display.display_prediction_attention("I'm going to shoot you!")
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/1520622701/model.ckpt-300
# Not toxic
# <style  type="text/css" >
#     #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col0 {
#             background-color:  #ffd7d7;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col1 {
#             background-color:  #ffe3e3;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col2 {
#             background-color:  #ffe1e1;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col3 {
#             background-color:  #ffb7b7;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col4 {
#             background-color:  #ffbdbd;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col5 {
#             background-color:  #fff6f6;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col6 {
#             background-color:  #fffcfc;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col7 {
#             background-color:  #fffefe;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col8 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col9 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col10 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col11 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col12 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col13 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col14 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col15 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col16 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col17 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col18 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col19 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col20 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col21 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col22 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col23 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col24 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col25 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col26 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col27 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col28 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col29 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col30 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col31 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col32 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col33 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col34 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col35 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col36 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col37 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col38 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col39 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col40 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col41 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col42 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col43 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col44 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col45 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col46 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col47 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col48 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col49 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col50 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col51 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col52 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col53 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col54 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col55 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col56 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col57 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col58 {
#             background-color:  #ffffff;
#         }    #T_201bea0c_23cf_11e8_b159_784f439c84abrow0_col59 {
#             background-color:  #ffffff;
#         }</style>
# <table id="T_201bea0c_23cf_11e8_b159_784f439c84ab" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >0</th>
#         <th class="col_heading level0 col1" >1</th>
#         <th class="col_heading level0 col2" >2</th>
#         <th class="col_heading level0 col3" >3</th>
#         <th class="col_heading level0 col4" >4</th>
#         <th class="col_heading level0 col5" >5</th>
#         <th class="col_heading level0 col6" >6</th>
#         <th class="col_heading level0 col7" >7</th>
#         <th class="col_heading level0 col8" >8</th>
#         <th class="col_heading level0 col9" >9</th>
#         <th class="col_heading level0 col10" >10</th>
#         <th class="col_heading level0 col11" >11</th>
#         <th class="col_heading level0 col12" >12</th>
#         <th class="col_heading level0 col13" >13</th>
#         <th class="col_heading level0 col14" >14</th>
#         <th class="col_heading level0 col15" >15</th>
#         <th class="col_heading level0 col16" >16</th>
#         <th class="col_heading level0 col17" >17</th>
#         <th class="col_heading level0 col18" >18</th>
#         <th class="col_heading level0 col19" >19</th>
#         <th class="col_heading level0 col20" >20</th>
#         <th class="col_heading level0 col21" >21</th>
#         <th class="col_heading level0 col22" >22</th>
#         <th class="col_heading level0 col23" >23</th>
#         <th class="col_heading level0 col24" >24</th>
#         <th class="col_heading level0 col25" >25</th>
#         <th class="col_heading level0 col26" >26</th>
#         <th class="col_heading level0 col27" >27</th>
#         <th class="col_heading level0 col

# %%
display.display_prediction_attention("Oh shoot. Well alright.")
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/1520622701/model.ckpt-300
# Not toxic
# <style  type="text/css" >
#     #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col0 {
#             background-color:  #ffb7b7;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col1 {
#             background-color:  #ff8888;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col2 {
#             background-color:  #ffe4e4;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col3 {
#             background-color:  #ffe6e6;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col4 {
#             background-color:  #fffbfb;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col5 {
#             background-color:  #fffefe;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col6 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col7 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col8 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col9 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col10 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col11 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col12 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col13 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col14 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col15 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col16 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col17 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col18 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col19 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col20 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col21 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col22 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col23 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col24 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col25 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col26 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col27 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col28 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col29 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col30 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col31 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col32 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col33 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col34 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col35 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col36 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col37 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col38 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col39 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col40 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col41 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col42 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col43 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col44 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col45 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col46 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col47 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col48 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col49 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col50 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col51 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col52 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col53 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col54 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col55 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col56 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col57 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col58 {
#             background-color:  #ffffff;
#         }    #T_20d32bb8_23cf_11e8_a53f_784f439c84abrow0_col59 {
#             background-color:  #ffffff;
#         }</style>
# <table id="T_20d32bb8_23cf_11e8_a53f_784f439c84ab" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >0</th>
#         <th class="col_heading level0 col1" >1</th>
#         <th class="col_heading level0 col2" >2</th>
#         <th class="col_heading level0 col3" >3</th>
#         <th class="col_heading level0 col4" >4</th>
#         <th class="col_heading level0 col5" >5</th>
#         <th class="col_heading level0 col6" >6</th>
#         <th class="col_heading level0 col7" >7</th>
#         <th class="col_heading level0 col8" >8</th>
#         <th class="col_heading level0 col9" >9</th>
#         <th class="col_heading level0 col10" >10</th>
#         <th class="col_heading level0 col11" >11</th>
#         <th class="col_heading level0 col12" >12</th>
#         <th class="col_heading level0 col13" >13</th>
#         <th class="col_heading level0 col14" >14</th>
#         <th class="col_heading level0 col15" >15</th>
#         <th class="col_heading level0 col16" >16</th>
#         <th class="col_heading level0 col17" >17</th>
#         <th class="col_heading level0 col18" >18</th>
#         <th class="col_heading level0 col19" >19</th>
#         <th class="col_heading level0 col20" >20</th>
#         <th class="col_heading level0 col21" >21</th>
#         <th class="col_heading level0 col22" >22</th>
#         <th class="col_heading level0 col23" >23</th>
#         <th class="col_heading level0 col24" >24</th>
#         <th class="col_heading level0 col25" >25</th>
#         <th class="col_heading level0 col26" >26</th>
#         <th class="col_heading level0 col27" >27</th>
#         <th class="col_heading level0 col

# %%
display.display_prediction_attention("First of all who the fuck died and made you the god.")
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/1520622701/model.ckpt-300
# Toxic
# <style  type="text/css" >
#     #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col0 {
#             background-color:  #fffefe;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col1 {
#             background-color:  #fffefe;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col2 {
#             background-color:  #fffcfc;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col3 {
#             background-color:  #fffcfc;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col4 {
#             background-color:  #fffafa;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col5 {
#             background-color:  #ff2c2c;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col6 {
#             background-color:  #fff9f9;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col7 {
#             background-color:  #fffbfb;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col8 {
#             background-color:  #fffcfc;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col9 {
#             background-color:  #fffafa;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col10 {
#             background-color:  #fffdfd;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col11 {
#             background-color:  #fffbfb;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col12 {
#             background-color:  #ffffff;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col13 {
#             background-color:  #ffffff;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col14 {
#             background-color:  #ffffff;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col15 {
#             background-color:  #ffffff;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col16 {
#             background-color:  #ffffff;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col17 {
#             background-color:  #ffffff;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col18 {
#             background-color:  #ffffff;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col19 {
#             background-color:  #ffffff;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col20 {
#             background-color:  #ffffff;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col21 {
#             background-color:  #ffffff;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col22 {
#             background-color:  #ffffff;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col23 {
#             background-color:  #ffffff;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col24 {
#             background-color:  #ffffff;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col25 {
#             background-color:  #ffffff;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col26 {
#             background-color:  #ffffff;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col27 {
#             background-color:  #ffffff;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col28 {
#             background-color:  #ffffff;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col29 {
#             background-color:  #ffffff;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col30 {
#             background-color:  #ffffff;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col31 {
#             background-color:  #ffffff;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col32 {
#             background-color:  #ffffff;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col33 {
#             background-color:  #ffffff;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col34 {
#             background-color:  #ffffff;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col35 {
#             background-color:  #ffffff;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col36 {
#             background-color:  #ffffff;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col37 {
#             background-color:  #ffffff;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col38 {
#             background-color:  #ffffff;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col39 {
#             background-color:  #ffffff;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col40 {
#             background-color:  #ffffff;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col41 {
#             background-color:  #ffffff;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col42 {
#             background-color:  #ffffff;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col43 {
#             background-color:  #ffffff;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col44 {
#             background-color:  #ffffff;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col45 {
#             background-color:  #ffffff;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col46 {
#             background-color:  #ffffff;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col47 {
#             background-color:  #ffffff;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col48 {
#             background-color:  #ffffff;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col49 {
#             background-color:  #ffffff;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col50 {
#             background-color:  #ffffff;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col51 {
#             background-color:  #ffffff;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col52 {
#             background-color:  #ffffff;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col53 {
#             background-color:  #ffffff;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col54 {
#             background-color:  #ffffff;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col55 {
#             background-color:  #ffffff;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col56 {
#             background-color:  #ffffff;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col57 {
#             background-color:  #ffffff;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col58 {
#             background-color:  #ffffff;
#         }    #T_2195c65a_23cf_11e8_9950_784f439c84abrow0_col59 {
#             background-color:  #ffffff;
#         }</style>
# <table id="T_2195c65a_23cf_11e8_9950_784f439c84ab" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >0</th>
#         <th class="col_heading level0 col1" >1</th>
#         <th class="col_heading level0 col2" >2</th>
#         <th class="col_heading level0 col3" >3</th>
#         <th class="col_heading level0 col4" >4</th>
#         <th class="col_heading level0 col5" >5</th>
#         <th class="col_heading level0 col6" >6</th>
#         <th class="col_heading level0 col7" >7</th>
#         <th class="col_heading level0 col8" >8</th>
#         <th class="col_heading level0 col9" >9</th>
#         <th class="col_heading level0 col10" >10</th>
#         <th class="col_heading level0 col11" >11</th>
#         <th class="col_heading level0 col12" >12</th>
#         <th class="col_heading level0 col13" >13</th>
#         <th class="col_heading level0 col14" >14</th>
#         <th class="col_heading level0 col15" >15</th>
#         <th class="col_heading level0 col16" >16</th>
#         <th class="col_heading level0 col17" >17</th>
#         <th class="col_heading level0 col18" >18</th>
#         <th class="col_heading level0 col19" >19</th>
#         <th class="col_heading level0 col20" >20</th>
#         <th class="col_heading level0 col21" >21</th>
#         <th class="col_heading level0 col22" >22</th>
#         <th class="col_heading level0 col23" >23</th>
#         <th class="col_heading level0 col24" >24</th>
#         <th class="col_heading level0 col25" >25</th>
#         <th class="col_heading level0 col26" >26</th>
#         <th class="col_heading level0 col27" >27</th>
#         <th class="col_heading level0 col

# %%
display.display_prediction_attention("Gosh darn it!")
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/1520622701/model.ckpt-300
# Toxic
# <style  type="text/css" >
#     #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col0 {
#             background-color:  #ffcaca;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col1 {
#             background-color:  #ff6666;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col2 {
#             background-color:  #ffe8e8;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col3 {
#             background-color:  #fff4f4;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col4 {
#             background-color:  #fffafa;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col5 {
#             background-color:  #fffdfd;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col6 {
#             background-color:  #fffefe;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col7 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col8 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col9 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col10 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col11 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col12 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col13 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col14 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col15 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col16 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col17 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col18 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col19 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col20 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col21 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col22 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col23 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col24 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col25 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col26 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col27 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col28 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col29 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col30 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col31 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col32 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col33 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col34 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col35 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col36 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col37 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col38 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col39 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col40 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col41 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col42 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col43 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col44 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col45 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col46 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col47 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col48 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col49 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col50 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col51 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col52 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col53 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col54 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col55 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col56 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col57 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col58 {
#             background-color:  #ffffff;
#         }    #T_2283a000_23cf_11e8_b76c_784f439c84abrow0_col59 {
#             background-color:  #ffffff;
#         }</style>
# <table id="T_2283a000_23cf_11e8_b76c_784f439c84ab" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >0</th>
#         <th class="col_heading level0 col1" >1</th>
#         <th class="col_heading level0 col2" >2</th>
#         <th class="col_heading level0 col3" >3</th>
#         <th class="col_heading level0 col4" >4</th>
#         <th class="col_heading level0 col5" >5</th>
#         <th class="col_heading level0 col6" >6</th>
#         <th class="col_heading level0 col7" >7</th>
#         <th class="col_heading level0 col8" >8</th>
#         <th class="col_heading level0 col9" >9</th>
#         <th class="col_heading level0 col10" >10</th>
#         <th class="col_heading level0 col11" >11</th>
#         <th class="col_heading level0 col12" >12</th>
#         <th class="col_heading level0 col13" >13</th>
#         <th class="col_heading level0 col14" >14</th>
#         <th class="col_heading level0 col15" >15</th>
#         <th class="col_heading level0 col16" >16</th>
#         <th class="col_heading level0 col17" >17</th>
#         <th class="col_heading level0 col18" >18</th>
#         <th class="col_heading level0 col19" >19</th>
#         <th class="col_heading level0 col20" >20</th>
#         <th class="col_heading level0 col21" >21</th>
#         <th class="col_heading level0 col22" >22</th>
#         <th class="col_heading level0 col23" >23</th>
#         <th class="col_heading level0 col24" >24</th>
#         <th class="col_heading level0 col25" >25</th>
#         <th class="col_heading level0 col26" >26</th>
#         <th class="col_heading level0 col27" >27</th>
#         <th class="col_heading level0 col

# %%
display.display_prediction_attention("God damn it!")
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/1520622701/model.ckpt-300
# Toxic
# <style  type="text/css" >
#     #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col0 {
#             background-color:  #ffd5d5;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col1 {
#             background-color:  #ff5151;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col2 {
#             background-color:  #ffebeb;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col3 {
#             background-color:  #fff6f6;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col4 {
#             background-color:  #fffbfb;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col5 {
#             background-color:  #fffdfd;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col6 {
#             background-color:  #fffefe;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col7 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col8 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col9 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col10 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col11 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col12 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col13 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col14 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col15 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col16 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col17 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col18 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col19 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col20 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col21 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col22 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col23 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col24 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col25 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col26 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col27 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col28 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col29 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col30 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col31 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col32 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col33 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col34 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col35 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col36 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col37 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col38 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col39 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col40 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col41 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col42 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col43 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col44 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col45 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col46 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col47 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col48 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col49 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col50 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col51 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col52 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col53 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col54 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col55 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col56 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col57 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col58 {
#             background-color:  #ffffff;
#         }    #T_2344ac64_23cf_11e8_8b72_784f439c84abrow0_col59 {
#             background-color:  #ffffff;
#         }</style>
# <table id="T_2344ac64_23cf_11e8_8b72_784f439c84ab" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >0</th>
#         <th class="col_heading level0 col1" >1</th>
#         <th class="col_heading level0 col2" >2</th>
#         <th class="col_heading level0 col3" >3</th>
#         <th class="col_heading level0 col4" >4</th>
#         <th class="col_heading level0 col5" >5</th>
#         <th class="col_heading level0 col6" >6</th>
#         <th class="col_heading level0 col7" >7</th>
#         <th class="col_heading level0 col8" >8</th>
#         <th class="col_heading level0 col9" >9</th>
#         <th class="col_heading level0 col10" >10</th>
#         <th class="col_heading level0 col11" >11</th>
#         <th class="col_heading level0 col12" >12</th>
#         <th class="col_heading level0 col13" >13</th>
#         <th class="col_heading level0 col14" >14</th>
#         <th class="col_heading level0 col15" >15</th>
#         <th class="col_heading level0 col16" >16</th>
#         <th class="col_heading level0 col17" >17</th>
#         <th class="col_heading level0 col18" >18</th>
#         <th class="col_heading level0 col19" >19</th>
#         <th class="col_heading level0 col20" >20</th>
#         <th class="col_heading level0 col21" >21</th>
#         <th class="col_heading level0 col22" >22</th>
#         <th class="col_heading level0 col23" >23</th>
#         <th class="col_heading level0 col24" >24</th>
#         <th class="col_heading level0 col25" >25</th>
#         <th class="col_heading level0 col26" >26</th>
#         <th class="col_heading level0 col27" >27</th>
#         <th class="col_heading level0 col

# %%
display.display_prediction_attention("Or else I'll cure your virginity from the wrong hole")
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/1520622701/model.ckpt-300
# Toxic
# <style  type="text/css" >
#     #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col0 {
#             background-color:  #fff1f1;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col1 {
#             background-color:  #fff2f2;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col2 {
#             background-color:  #fff1f1;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col3 {
#             background-color:  #ffd2d2;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col4 {
#             background-color:  #ffcccc;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col5 {
#             background-color:  #ffeded;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col6 {
#             background-color:  #ffeeee;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col7 {
#             background-color:  #ffeeee;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col8 {
#             background-color:  #ffeeee;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col9 {
#             background-color:  #ffd6d6;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col10 {
#             background-color:  #fffefe;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col11 {
#             background-color:  #ffffff;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col12 {
#             background-color:  #ffffff;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col13 {
#             background-color:  #ffffff;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col14 {
#             background-color:  #ffffff;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col15 {
#             background-color:  #ffffff;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col16 {
#             background-color:  #ffffff;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col17 {
#             background-color:  #ffffff;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col18 {
#             background-color:  #ffffff;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col19 {
#             background-color:  #ffffff;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col20 {
#             background-color:  #ffffff;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col21 {
#             background-color:  #ffffff;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col22 {
#             background-color:  #ffffff;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col23 {
#             background-color:  #ffffff;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col24 {
#             background-color:  #ffffff;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col25 {
#             background-color:  #ffffff;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col26 {
#             background-color:  #ffffff;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col27 {
#             background-color:  #ffffff;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col28 {
#             background-color:  #ffffff;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col29 {
#             background-color:  #ffffff;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col30 {
#             background-color:  #ffffff;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col31 {
#             background-color:  #ffffff;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col32 {
#             background-color:  #ffffff;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col33 {
#             background-color:  #ffffff;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col34 {
#             background-color:  #ffffff;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col35 {
#             background-color:  #ffffff;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col36 {
#             background-color:  #ffffff;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col37 {
#             background-color:  #ffffff;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col38 {
#             background-color:  #ffffff;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col39 {
#             background-color:  #ffffff;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col40 {
#             background-color:  #ffffff;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col41 {
#             background-color:  #ffffff;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col42 {
#             background-color:  #ffffff;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col43 {
#             background-color:  #ffffff;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col44 {
#             background-color:  #ffffff;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col45 {
#             background-color:  #ffffff;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col46 {
#             background-color:  #ffffff;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col47 {
#             background-color:  #ffffff;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col48 {
#             background-color:  #ffffff;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col49 {
#             background-color:  #ffffff;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col50 {
#             background-color:  #ffffff;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col51 {
#             background-color:  #ffffff;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col52 {
#             background-color:  #ffffff;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col53 {
#             background-color:  #ffffff;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col54 {
#             background-color:  #ffffff;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col55 {
#             background-color:  #ffffff;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col56 {
#             background-color:  #ffffff;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col57 {
#             background-color:  #ffffff;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col58 {
#             background-color:  #ffffff;
#         }    #T_23f5af0a_23cf_11e8_8feb_784f439c84abrow0_col59 {
#             background-color:  #ffffff;
#         }</style>
# <table id="T_23f5af0a_23cf_11e8_8feb_784f439c84ab" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >0</th>
#         <th class="col_heading level0 col1" >1</th>
#         <th class="col_heading level0 col2" >2</th>
#         <th class="col_heading level0 col3" >3</th>
#         <th class="col_heading level0 col4" >4</th>
#         <th class="col_heading level0 col5" >5</th>
#         <th class="col_heading level0 col6" >6</th>
#         <th class="col_heading level0 col7" >7</th>
#         <th class="col_heading level0 col8" >8</th>
#         <th class="col_heading level0 col9" >9</th>
#         <th class="col_heading level0 col10" >10</th>
#         <th class="col_heading level0 col11" >11</th>
#         <th class="col_heading level0 col12" >12</th>
#         <th class="col_heading level0 col13" >13</th>
#         <th class="col_heading level0 col14" >14</th>
#         <th class="col_heading level0 col15" >15</th>
#         <th class="col_heading level0 col16" >16</th>
#         <th class="col_heading level0 col17" >17</th>
#         <th class="col_heading level0 col18" >18</th>
#         <th class="col_heading level0 col19" >19</th>
#         <th class="col_heading level0 col20" >20</th>
#         <th class="col_heading level0 col21" >21</th>
#         <th class="col_heading level0 col22" >22</th>
#         <th class="col_heading level0 col23" >23</th>
#         <th class="col_heading level0 col24" >24</th>
#         <th class="col_heading level0 col25" >25</th>
#         <th class="col_heading level0 col26" >26</th>
#         <th class="col_heading level0 col27" >27</th>
#         <th class="col_heading level0 col

# %%
display.display_prediction_attention("You're not that smart are you?")
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/1520622701/model.ckpt-300
# Not toxic
# <style  type="text/css" >
#     #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col0 {
#             background-color:  #ffb2b2;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col1 {
#             background-color:  #ffe3e3;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col2 {
#             background-color:  #ffe5e5;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col3 {
#             background-color:  #ffe5e5;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col4 {
#             background-color:  #ffdede;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col5 {
#             background-color:  #ffd4d4;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col6 {
#             background-color:  #fff6f6;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col7 {
#             background-color:  #fffbfb;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col8 {
#             background-color:  #fffefe;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col9 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col10 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col11 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col12 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col13 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col14 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col15 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col16 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col17 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col18 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col19 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col20 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col21 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col22 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col23 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col24 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col25 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col26 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col27 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col28 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col29 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col30 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col31 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col32 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col33 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col34 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col35 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col36 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col37 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col38 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col39 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col40 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col41 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col42 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col43 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col44 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col45 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col46 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col47 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col48 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col49 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col50 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col51 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col52 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col53 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col54 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col55 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col56 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col57 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col58 {
#             background-color:  #ffffff;
#         }    #T_24aa2d90_23cf_11e8_aab7_784f439c84abrow0_col59 {
#             background-color:  #ffffff;
#         }</style>
# <table id="T_24aa2d90_23cf_11e8_aab7_784f439c84ab" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >0</th>
#         <th class="col_heading level0 col1" >1</th>
#         <th class="col_heading level0 col2" >2</th>
#         <th class="col_heading level0 col3" >3</th>
#         <th class="col_heading level0 col4" >4</th>
#         <th class="col_heading level0 col5" >5</th>
#         <th class="col_heading level0 col6" >6</th>
#         <th class="col_heading level0 col7" >7</th>
#         <th class="col_heading level0 col8" >8</th>
#         <th class="col_heading level0 col9" >9</th>
#         <th class="col_heading level0 col10" >10</th>
#         <th class="col_heading level0 col11" >11</th>
#         <th class="col_heading level0 col12" >12</th>
#         <th class="col_heading level0 col13" >13</th>
#         <th class="col_heading level0 col14" >14</th>
#         <th class="col_heading level0 col15" >15</th>
#         <th class="col_heading level0 col16" >16</th>
#         <th class="col_heading level0 col17" >17</th>
#         <th class="col_heading level0 col18" >18</th>
#         <th class="col_heading level0 col19" >19</th>
#         <th class="col_heading level0 col20" >20</th>
#         <th class="col_heading level0 col21" >21</th>
#         <th class="col_heading level0 col22" >22</th>
#         <th class="col_heading level0 col23" >23</th>
#         <th class="col_heading level0 col24" >24</th>
#         <th class="col_heading level0 col25" >25</th>
#         <th class="col_heading level0 col26" >26</th>
#         <th class="col_heading level0 col27" >27</th>
#         <th class="col_heading level0 col

# %% [markdown]
# # Save and Load Model

# %%
def serving_input_receiver_fn():
    inputs = {WORDS_FEATURE: tf.placeholder(shape=[None, MAX_DOCUMENT_LENGTH], dtype=tf.int64)}
    return tf.estimator.export.ServingInputReceiver(inputs, inputs)

current_time = str(int(time.time()))
export_dir_base = "models/200_length_300_embeding/"

full_model_dir = classifier.export_savedmodel(export_dir_base=export_dir_base, serving_input_receiver_fn=serving_input_receiver_fn)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/1521593965/model.ckpt-300
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: models/200_length_300_embeding/temp-1521594535/saved_model.pb

# %%
with open("data/tweets.csv", "r") as f:
    tweet_df = pd.read_csv(f, index_col=0)

# %%
tweets = tweet_df['tweet'].values.tolist()
labels = (tweet_df['label'] == 'H').values.tolist()

# %%
x_test = vocab_processor.transform(tweets)
x_test = np.array(list(x_test))

# %%
full_model_dir = "models/200_length_300_embeding/1521594535/"

with tf.Session() as sess:
    tf.saved_model.loader.load(sess, [tf.saved_model.tag_constants.SERVING], full_model_dir)
    predictor   = tf.contrib.predictor.from_saved_model(full_model_dir)
    output_dict = predictor({WORDS_FEATURE:x_test})
    predicted_label = output_dict["class"] # label
    attention = output_dict["attention"]
    prob = output_dict["prob"]
# Out:
# INFO:tensorflow:Restoring parameters from models/200_length_300_embeding/1521594535/variables/variables
# INFO:tensorflow:Restoring parameters from models/200_length_300_embeding/1521594535/variables/variables

# %%
cnt = 0
for ind, l in enumerate(predicted_label):
    cnt += (l == int(labels[ind]))
print(cnt)
# Out:
# 1150

# %%
tokenizer = tf.contrib.learn.preprocessing.tokenizer
for ind, attentions in enumerate(attention):
    text = tweets[ind]
    tokens = list(tokenizer([text]))[0]
    l = len(tokens)
    cur_a = attentions[:l]
    cur_a = sorted([(a[0], ind) for ind, a in enumerate(cur_a)])
    print([tokens[c[1]] for c in cur_a])
# Out:
# ['street', 'town', 'from', 'to', 'the', 'lights', 'need', 'swing', 'niggers', 'fucking', 'fucking', 'of', 'one', 'you', 'Jerryls', 'deray', 'every', 'Kidz']
# ['cGF6XkwOvv', 't', 'imagine', 'frumpy', 'https', 'co', 'looks', 'as', 'would', 'She', 'exactly', 'as', 'you', 'God', 'Oh']
# ['Jews', 'the', 'of', 'Battles']
# ['J83pM8lzHn', 'https', 't', 'co', 'cunt', 'sick', 'RT', 'right', 'Redux', 'Spectre', 'a', "You're"]
# ['98', 'Quran', 'creatures', 'all', '6', '-', 'and', 'of', 'RECITE', 'vilest', 'the', 'Christians', 'are', 'Jews', 'the', 'idiot', 'Actually', 'Sadiq01', 'Islam', 'Adnan', 'what', 'is', 'incites', 'hatred']
# ['Jibz212121', '-', 'Jews', 'the', 'Fuck']
# ['Commentator', '8LOgXy', 'Ze', 'UW', 'The', 't', 'Commentator', 'co', 'via', 'all', 'The', 'http', 'Jews', '-', 'the', 'shoot', 'tells', 'kids', 'Hamas', 'to']
# ['racism-whats-good-for-jews-is-good-for-goyim', 'real', 'very', 'whitegenocide', "It's", 'of', 'heard', 'Have', 'you']
# ['old', 'and', 'and', 'tired', 'I', 'god', 'look', 'Jews', 'the', 'fuck', 'B123Micky', 'like']
# ['0P47ovu3', 'ML', 'infested', 't', 'out', 'and', 'have', 'https', 'co', 'lands', 'now', 'it', 'destroying', 'jews', 'is', 'the', 'but', 'so', 'true']
# ['fascist', 'retard', 'fucking', 'Boot', 'Trump', "isn't", 'a', 'Max', 'you']
# ['4qNGHimjuh', 'n', 'nhttps', 'Libya', 't', 'died', 'co', 'until', 'he', 'President', 'Muslim', 'ass', 'a', 'rape', 'why', 'in', 'the', "that's", 'Muslims', 'she', 'gays', 'had', 'Muslims', 'Hillary', 'loves', 'amp']
# ['they', 'dislike', 'degrade', 'amp', 'people', 'privileges', 'abuse', 'to', 'they', 'their', 'abusive', 'use', 'much', 'husband', 'an', 'as', 'feminists', 'Radfem', 'as', 'Fs', 'are', 'TER', 'Tara_Hewitt']
# ['fucking', 'faggot', 'chubby', 'You']
# ['w3SQ5zX6mH', 'Crooks', 't', 'https', 'Liars', 'and', "'Dispose", 'co', "Jews'", 'Of', 'To', 'Space', 'The', 'Drumpf', 'Give', 'RT', 'mch7576', 'David', 'Duke', 'To', 'Wants']
# ['bitch', 'Pakistani', 'fuck', 'never', 'disgusting', 'a', "I'd"]
# ['lmfao', 'welfare', 'and', 'off', 'free', 'housing', 'Karzan35o2', 'Ameeno93', 'Dopeness', 'living', "y'all", 'RT', 'Jews', 'the', 'Est', 'lol', 'but']
# ['vMIbYmBbBg', 'https', 't', 'post-white', 'co', 'Genocide', 'they', 'one', 'a', 'what', 'want', 'White', 'post-racial', 'Mcom', 'There', 'is', 'never', 'a', 'RT', 'world', 'be', 'WL', 'will']
# ['white', 'set', 'in', 'into', 'foot', 'children', 'they', 'defenseless', 'that', 'white', "wouldn't", 'schools', 'themselves', 'throwing', 'Anti-whites', 'Trainspotter001', 'RT', 'support']
# ['YOU', 'WILL', 'baby', "It's", 'an', 'Nazis', 'extermination', 'WITH', 'different', 'incident', 'DEAL', 'MURDER', 'killing', 'GOD', 'Jews', 'than', 'no', 'the', 'is', 'the', 'Murdering']
# ['up', 'shut', 'RT', 'Wendy', 'club', 'For', 'recently', '-', 'unless', 'Club', 'joined', 'LDavis', 'Allan', 'the', 'Jews', 'Jesus', "There's", "you've", 'Priest', 'a']
# ['for', 'Jews', 'who', 'the', 'wonder', 'Humm', 'Remember', 'graves', 'now', 'digging', 'they', 'already', 'mass', 'word', 'are', 'sidekick78', 'is']
# ['t5irjuWPzG', 'https', 't', 'NRx', 'whitegenocide', 'https', 'co', 'Sweden', 'arrested', 'in', 'whites', 'attack', 'planning', 'against', 'Muslim', 'terrorist', 'RT', 'Thug_Violence']
# ['bHs8kwV8KG', 'Fy1', 't', 'ZOBQY', 'https', 'Wu', 'co', 'Kacou', 'https', 't', 'Philippe', 'Prophet', 'co', 'Jews', 'Prophet', 'the', 'of', 'Kacou', 'Philippe', 'kadifson']
# ['A', 'Bravo', 'Haber', 'Bravo', 'Jews', 'the', 'of', 'course', 'are', 'conspiracy', 'of', 'this', 'perpetrators', 'The']
# ['victim', 'new', 'a', 'PC', 'finding', 'Spacekatgal', 'harder', 'like', 'or', 'to', 'a', 'ways', 'building', 'find', 'act', 'do', 'you', 'What']
# ['UCLA', 'lore', 'nMainak', 'n', 'Sarkar', 'shooting', 'everybody', 'UCLA', 'https', 'of', 't', 'male', '\xc3', 'Shooting', 'white', 'co', 'fucking', 'RT', 'Here', 'static_boolean', 'the', '6ft', 'tall', 'is']
# ['Wak', 'Gdl7ZBO2Jj', 'Awareness', 'Month', 'Muslim', 't', 'https', 'Prays', 'for', 'co', 'Is', 'Annihilation', 'Jews', 'Mosque', 'Sheikh', 'the', 'RT', 'the', 'Al-Aqsa', 'kafirkaty', 'This', 'Islam']
# ['Jews', 'the', 'killing', 'Violets', 'still', "I'm", 'still', 'red', 'still', 'Sugar', 'still', 'Roses', 'blue', 'are', 'Hitler', 'RT', 'are', 'And', 'sweet', 'Dictator', 'is']
# ['orde\xc3', 'of', 'highest', 'the', '\xc2', '\xc2', '\xc2', '\xc3', '\xc3', '\xc2', 'idiot', 'attack', 'soil', 'ISIS', 'American', 'reaction', 'to', 'on', 'the', 'RT', 'If', 'first', 'thee_csmith121', 'to', 'disarm', 'an', 'is', 'your', 'Americans', 'are', 'you']
# ['6q6X76H0U2', 't', 'co', 'http', 'Jews', 'kill', 'History', 'the', 'Terrorism', 'Long', 'of', 'amp', 'Trying', 'to', 'Palestinian', 'iA7med80']
# ['Ob9e4Zph', 'Lo', 'https', 't', 'priorities', 'co', 'raped', 'white', 'were', 'girls', 'did', 'that', '1400', 'community', 'whilst', 'same', 'nothing', 'The']
# ['sweden', 'http', 'Purge', 'Democrats', 'Gov', 'person', 'down', 'Genocide', 'Aodh', 'You', 'SD', 'White', 'RT', 'Labour', 'chasing', 'Sweden', 'White', 'Lady', 'the', 'Diversity', 'last', 'means']
# ['All', '_', 'Jews', 'Apartheid', 'warming', 'banks', 'planet', 'War', 'Global', 'Pluto', '11', "isn't", '9', 'Jews', 'a', 'World', 'blame', 'Always', 'the', 'yes', 'deray', 'Mario_Greenly']
# ['Ef3t2tvp', 'Fg', 'https', 't', 'co', 'too', 'retards', 'whores', 'and', 'Her', 'probably', 'family', 'are']
# ['leaving', 'into', 'Piggy', 'quT9pGC0wD', 'are', 'Merkel', 'Cameron', 'Nice', 'Theresa', 'Europe', 't', 'and', 'people', 'co', 'Mother', 'http', 'all', 'Jews', 'the', 'kill', 'We', 'need', 'Islam', 'to', 'UK']
# ['38sm9V3b', 'SF', 'https', 't', 'Feminism', 'antifeminism', 'co', 'antifeminist', 'Is', 'Feminism', 'Awful', 'Against', 'Women', 'Public', 'by', 'FIRED', 'clementine_ford', 'FEMINAZI']
# ['YOU', 'FUCKING', 'NIGGER', 'FOR', 'THAT', 'MASTERWANKY', 'REPORT', 'NAME', 'TAKING', 'IM', 'EVERYONE', 'SPAM']
# ['whore', 'attention', 'fucking', 'about', 'about', "isn't", 'This', 'andrewsjake4', 'make', 'this', 'yourself', "Don't", 'you', 'you']
# ['e3', 'gaming', 'urination', 'community', 'public', 'grail', 'holy', 'fact', 'conference', 'of', 'the', 'the', 'known', 'little', 'is', 'RT', 'the', 'dril', 'considered']
# ['Tube', 'w0p05vObFZ', 'via', 'Father', 'You', 'https', 'A', 'co', 't', 'Of', 'But', "Doesn't", 'cks', 'Picker', 'U', 'Bad', 'That', 'Make', 'D', 'a', 'Whore', 'Look', "You're"]
# ['Brannon1066', 'on', 'chambers', 'a', 'that', 'loop', 'run', 'should', 'gas', "Whoever's", 'to', 'running', 'culpability', 'admit', 'Nice', 'of', 'the', 'Jews', 'the', 'their']
# ['cunt', 'what', 'Oh', 'kmdes', 'my', 'a']
# ['Hitler', 'Salute', 'a', 'I', 'To', 'I', 'few', 'of', 'world', 'left', 'the', 'the', "didn't", 'world', 'why', 'to', 'show', 'but', 'jews', 'all', 'the', 'killed', 'would', 'I', 'have']
# ['of', 'Gaza', 'and', 'honour', 'the', 'Muslims', 'Allaah', 'uplift', 'and', '6-', 'May', 'expose', 'and', 'to', 'OFC', 'Life', 'Jews', 'continue', 'And', 'RT', 'the', 'disgrace', 'Islam']
# ['A9yV', 'Yf', 't', 'co', '5mSV5dPC', 'http', 'KW', 'they', 'greed', 't', 'and', 'co', 'http', 'how', 'by', 'Bushwick', 'rule', 'shop', "Jews'", 'owner', 'RT', 'Brokelyn', 'coffee', 'thoughts', 'on', "'the", 'shares']
# ['where', 'they', 'they', 'to', 'Rats', 'muslims', 'back', 'must', 'from', 'send', 'come', 'UK', 'Hope', 'Living', 'be', 'In', 'Fucking', 'RT', 'clouzot_alive', 'Daily_Express']
# ['our', 'up', 'stuff', 'taking', 'made', 'away', 'Muslims', 'Fucking', 'RT', 'The_Paris_Angel']
# ['teaparty', 'being', 'with', 'Diversity', 'Genocide', 'destroyed', 'are', 'Whites', 'White', 'non-African', 'Only', 'Africa', 'non-Asian', 'or', 'Asia', 'turning', 'Nobody', 'is']
# ['banter', 'not', 'fly', 'the', 'while', 'up', 'its', 'a', '\xc3', '\xc3', '\xc2', '\xc2', '\xc2', '\xc3', '\xc2', '\xc3', '\xc2', 'to', 'next', 'him', 'moving', 'fuck', 'he', 'Beaverr_', 'couldnt']
# ['Important', 'Jews', 'education', 'the', 'yes', 'Ah']
# ['wo', 'it', 'Did', 'think', 'really', 'anyone', 'attacks', 'suffered', 'All', 'amp', 'Jews', 'from', 'anti-Semitic', 'silently', 'the', 'RT', 'world', 'France', 'the', 'in', 'watched', 'summer', 'stevenburg']
# ['burning', 'all', 'they', 'Plainfield', 'know', 'north', 'you', 'all', 'out', 'in', 'are', 'Jews', 'the']
# ['whitepower', 'kkk', 'niggers', 'like', 'Vxii', 'Brettedaniels', 'RT', 'NSaNiTYxV', 'isabeaner', 'I', "don't", 'just', 'no']
# ['smackNY', 'Mepham', 'pretend', 'where', 'to', 'Italian', 'be', 'Jews', 'High', 'NY', 'the', 'SMACK', 'RT', 'Ayling', 'Brittaney']
# ['of', 'enemy', 'are', 'Jews', 'the', 'The', 'him', 'Christ', 'mockery', 'of', 'killed', 'defending', 'a', 'demons', 'the', 'make', 'who', 'Seventh', 'TRS', 'You', 'Son', 'RT', 'pantsukampf', 'Arlink', 'Andrew']
# ['long', "wasn't", 'that', 'had', 'it', 'holocaust', 'easy', 'Jews', 'me', 'the', 'If', 'asked', 'killed', 'you', 'and', 'Thickliciouss', 'then', 'beaten']
# ['2M6hCrMDQI', 'https', 't', 'FEMINIST', 'co', 'SHIT', 'FUCKING', 'A', 'HOLY']
# ['nrjAyL4FlE', 't', 'co', 'them', 'very', 'to', 'http', 'the', 'last', 'kill', 'one', 'for', 'Genocide', 'Muslim', 'Calls', '5', 'Count', 'New', 'and', 'of', 'Bad', 'the', 'RT', 'Blue', 'them', 'News', 'Jews']
# ['back', 'are', 'coming', 'Jews', 'not', "I'm", 'the', "I'm", 'fact', 'Judaism', 'about', 'thrilled', 'tweets', 'not', 'me', 'is', 'sending', 'in', 'Zionism', 'stop', 'RT', 'ashamed', 'justice4zion', 'Please']
# ['Z7T2bpqFcy', 'whitelivesmatter', 'watch', 'please', 'co', 't', 'https']
# ['ignorant', 'ones', 'the', 'not', 'all', 'we', 'blaming', 'are', 'Jews', 'the', 'just', 'course', 'if', 'Dakkentalz']
# ['ag\xc3', 'for', 'and', 'fraud', 'pay', 'violence', 'the', 'to', 'committed', "you've", 'made', 'be', 'fucking', 'will', 'You', 'people', 'kike', 'RT', 'used', 'to', 'rabite', 'jonathanweisman', 'it', 'get', 'you']
# ['jews', 'knows', 'everyone', 'created', 'links', 'were', 'by', 'the', 'bullshit', 'thank', 'to', 'links', 'need', 'jasonh2377', 'Spectre', 'your', "don't", 'Forever', 'no', 'your', 'you', 'i']
# ['Tfl0p6V3uZ', 't', 'co', '8lIsFHw1sE', 'Podcasts', 'Conflating', 'http', 'Dishonest', 'Meme', 'Israel', 'Latest', 'amp', 'co', 'The', 'gt', 'http', 't', 'Jews', 'PASSIONATE', 'MEDIA', 'JUSTICE', 'On']
# ['retarded', 'fucking', 'Melly', 'one_mrs_k', 'Selfelin', 'Moonbeam', 'do_mck', "you're"]
# ['and', 'Jews', 'champagne', 'Syrians', 'and', 'the', 'facial', 'naked', 'to', 'Israel', 'and', 'get', "let's", 'Kirill', 'Here', 'go', 'Was']
# ['unlawfully', 'riba', 'usury', 'and', 'peoples', 'they', 'wealth', 'consumed', 'though', 'even', 'Jews', 'with', 'the', 'to', 'invitations', 'meals', 'accepted', 'saw', 'Prophet', 'The']
# ['Kz', 'ZDIGDRSI', 't', 'https', 'co', 'Genocide', 'On', 'Whites', 'Yes', 'White', 'More', 'War', 'RT', 'Is', 'Electre']
# ['CCOT', 'TCOT', '3b12NZaE', 'RT', 'EL', 'Hamas', 'Destroy', 't', 'for', 'co', 'Wished', 'http', 'he', 'Jews', 'Hitler', 'called', 'finished', 'the', 'Holocaust', 'Rally', 'HAMAS', 'Pro']
# ['jews', 'do', 'neef', 'the', 'to', 'do', 'we', 'with', 'yourFriendEVA', 'What']
# ['our', 'they', 'can', 'they', 'steal', 'immortal', 'HUMANS', 'JEWS', 'can', 'DO', 'amp', 'humans', 'become', 'souls', 'THE', 'US', '1', '2', 'never', 'TO', 'NO', 'WHAT', 'never', 'MATTER', 'Redux', 'RT', 'Braveheart']
# ['UEP', 'Mrl', 'LZ', 'Py', 'https', 't', 'for', 'co', 'Jews', '-the', "It's", 'Stevenss', 'unhealthy', 'Whites', 'RT', 'to', 'Cora', 'care', 'about', 'their', 'race']
# ['Jews', 'likes', 'tell', 'nobody', 'to', 'me', 'lady', 'tried', 'This', 'Jews', 'the', 'hate', 'really', 'Do', 'ppl']
# ['96fxBT', 'SK', 'Kx', 't', 'co', 'For', 'http', 'Syria', 'The', 'War', 'Jews', 'Another']
# ['shut', 'fuck', 'and', 'manhandle', 'so', 'whore', 'hard', 'Dumb', 'dumb', 'whining', 'letting', 'and', 'start', 'up', 'Stop', 'me', 'you', 'you', 'cunt', 'you', 'a', 'like']
# ['seriousproblem', 'gio7579', 'would', 'he', 'wife', 'jews', 'fuckin', 'the', "wouldn't", 'he', 'dibo3742', 'be', 'the', 'guy', 'lil']
# ['fucking', 'nigger', 'itsshelbydoe', 'thanks', 'you']
# ['b', 'rioting', 'expression', 'targetted', 'race', 'simply', 'is', 'violent', 'Yes', 'majorly_vext', 'disagreement', 'bigotry', 'is']
# ['sounds', 'so', 'electric', 'a', 'only', 'fair', 'Its', 'fair', 'huge', '350', 'month', 'its', 'included', 'is', 'cunt', 'rooms', 'renting', 'Are', 'feministcupcake', 'in', 'your', 'you']
# ['Muslims', 'Murders', 'acompilce', 'Of', 'Governor', 'Fucking', 'to', 'Funded', 'the', 'Assistance', 'an', 'Boston', 'Goat', 'Terrorist', 'in', 'Department', 'are', 'Your', 'these', 'You', 'Mass']
# ['HELL', 'VLAD', 'BACK', 'JEWS', 'BE', 'THE', 'IT', 'BE', 'YOU', 'WILL', 'DONKEY', 'EUROPE', 'TO', 'CRIME', 'TO', 'A', 'A', 'SEND', 'CONTROLS', 'BRAYING', 'JEWISH', 'VLADIMIR', 'PUTIN', 'BLESS', 'WHEN', 'GOD']
# ['https', 'udgsFYg0qi', 'News', 'genocide', 't', 'and', 'co', 'of', 'accuse', 'Turkey', 'Berlin', 'submitted', 'to', 'by', 'Jews', 'Ankara', 'the', 'ovens', 'in', 'News', 'You', 'burned', 'Tyo']
# ['gLKA9rnQpJ', 't', 'co', 'Tcot', 'Blue', 'http', 'Unite', 'Blue', 'Lives', 'Lives', 'Black', 'Lives', 'White', 'Matter', 'Matter', 'Matter']
# ['man', 'camps', 'concentration', 'the', 'to', 'jews', 'the', 'sending', 'nazis', 'save', 'to', 'India', 'patients', 'like', 'to', "it's", "money''", 'may', 'send', 'lord', "''NHS", 'the', 'oh']
# ['IQ', 'sportsballers', 'Few', 'lt', 'brown', 'Jews', 'Low', 'The', 'the', '11', 'of', '9', 'millions', 'did', 'Of', 'killed', 'ISUS', '3', 'brown', 'but', 'since', 'Kaepernick', 'people', 'Allies', 'Weve', 'For', 'Veterans']
# ['https', 'and', 'Algerians', "it's", 'making', 'it', 'no', 'about', 'Jews', 'This', 'bones', 'times', "Army'", 'the', 'kill', 'vowing', "'Muslim", 'to', 'RT', 'another', 'Fatah', 'Tarek', 'comes', 'Here']
# ['smh', 'jews', 'all', 'killed', 'the', 'RT', 'If', 'mohammedalshaww', 'would', 'have', 'only', 'hitler']
# ['Pfunfe', 'Uj', 'CJ', 'https', "wasn't", 'shower', 't', 'co', 'out', 'it', 'really', 'a', 'found', 'Jews', 'When', 'the', 'Hitler', 'RT', 'Dictator']
# ['Adolf', 'them', 'Hitler', 'killing', 'know', 'was', 'I', 'to', 'of', 'why', 'I', 'some', 'them', 'left', 'let', 'but', 'all', 'you', 'the', 'Jews', 'could', 'have', 'killed', 'RT', 'Bumble_Beeeeee', 'I']
# ['rights', 'medal', 'human', 'fucking', 'Yet', 'for', 'as', 'tries', 'soon', 'it', 'a', 'he', 'wants', 'male', 'dude', 'a', 'eons', 'roles', 'doing', 'have', 'been', 'stereotypically', 'Women']
# ['nigger', 'fucking', 'watching', 'tweet', 'stop', 'me', 'you', 'you']
# ['escaping', 'There', 'for', 'no', 'Jews', 'culture', 'and', 'has', 'the', 'is', 'Currite', 'Lente', 'Now', 'had', 'sins', 'Every', 'Melly', 'religion', 'it', 'Moonbeam', 'RT', 'to', 'time', 'is', 'their', 'face']
# ['t', 'https', 'Trump2016', 'co', 'that', 'USA', 'Genocide', 'Hillary', 'of', 'was', 'Immigration', 'White', 'Clinton', '1965', 'Act', 'changed', '1950', 'White', 'In', 'census', 'RT', '90', '1776LD']
# ['t', 'whitegenocide', 'rapeculture', 'cdLnhry401', 'https', 'buses', 'https', 't', 'on', 'co', 'children', 'photographed', 'Aodh', 'amp', 'molested', 'RT', 'Lady', 'Swedish', 'Refugees']
# ['Nazi', 'a', 'like', 'whitepower', 'Screaming']
# ['dad', 'crippled', 'my', 'nipple', 'it', 'because', 'jews', 'at', 'growled', 'I', 'the']
# ['wigger', 'Power', 'White', 'first', 'not', 'Azzmador4Ever', 'to', 'we', 'if', 'OSbestof', 'you', 'get']
# ['and', 'innocent', 'of', 'people', 'blood', 'stained', 'with', 'the', 'mud', 'bloody', 'better', 'not', 'than', 'Awadi647', 'Daash', 'all', 'Shiites', 'and', 'same', 'the', 'in', 'Abdul', 'the', 'Jews', 'the']
# ['T', 'Gw', 'Fnmkskn', 't', 'http', 'co', 'niggers', 'fucking', 'xFallenn', 'zFoxxy', 'downstairs', 'you', 'im']
# ['8jfI6h3HPP', 'https', 'ANIMALS', 't', 'co', 'MUSLIM', 'FILTHY', 'FUCKING']
# ['for', 'them', 'hellfire', 'time', 'that', 'Jews', 'judgement', 'day', 'the', 'then', 'its', 'until', 'is', 'love', 'Christians']
# ['unjust', 'Jews', 'like', 'the', 'on', 'the', 'sword', 'of', 'the', 'Be', 'one']
# ['MURICA', 'stereotypical-SJW-white-imperialist-bigoted-Americunts', 'nSo', 'sup', 'Leader', 'summoned', 'GG', 'ashleylynch', 'Dwavenhobble', 'You', 'Antisocial', 'Max']
# ['kFAmaQJvSd', 't', 'co', 'they', 'and', 'Gaza', 'them', 'fight', 'http', 'Palestine', 'Free', 'Jews', 'are', 'because', 'Jews', 'the', 'hate', 'RT', 'HTalmas', 'We', "don't"]
# ['7AuRsUNN', 'Is', 'https', 'antifeminist', 'DJ', 't', 'Feminism', 'Feminism', 'Is', 'co', 'Awful', 'Feminism', 'Cancer', 'Against', 'Women', 'LOGIC', 'feminism', 'Ass', 'FEMINAZI', 'Dumb']
# ['t', 'CUL', 'codewords', 'http', 'Turalism', 'Multi', 'EDL', 'On', 'UKIP', '4', 'Genocide', 'War', 'Whites', 'Rotherham', 'White', 'Diversity', 'Assimilation', 'RT', '1776LD', 'ALL']
# ['on', 'Lord', 'Twitter', 'lies', 'livin', 'Kause', 'at', 'They', 'ya', 'me', 'confession', 'da', 'booth', 'at', 'to', 'need', 'mad', 'right', 'go', 'Dese', 'Bitchs', 'Life', 'in', 'b', 'Dnt', 'Bitch']
# ['Ai0n', 't', 'https', 'co', 'my', 'Coming', 'hold', 'First', 'to', 'believed', 'If', 'told', 'Jews', 'him', 'the', 'RT', 'At', 'Shincheonji_11', 'Jesus', 'who', 'the', 'in', 'truth', 'you', 'do', 'mean', 'What']
# ['playbook', 'feminist', 'the', 'bad', 'in', 'is', 'sex', 'all', 'okayultra', 'rjacksix', 'da5ch0', 'lol']
# ['Nuff', 'said', 'Muslims', 'fucking', 'Lover', 'LVIECELI', 'Dog', 'Omgmuslim', 'TOleary911', 'GSD', 'Its_omz']
# ['BOGGLING', 'MIND', 'PROPOGANDA', 'ALTHOUGH', 'SEMITIC', 'THE', 'JEWS', 'SIDING', 'ANTI', 'I', 'NAZIS', 'FIND', 'PERSONALLY', 'WITH', 'ITS', 'OBVIOUS', 'davidbarker95', 'YES']
# ['racist', 'nazi', 'jews', 'thought', 'I', 'holocaust', 'cunt', 'all', 'cunt', 'german', 'the', 'already', 'gassed', 'ya', 'missing', 'foreskin', 'would', 'Scraze', 'LJ', 'be', 'Why', 'I', 'you', 'my', 'you']
# ['Are', 'you', 'comparing', 'cunt', 'the', 'was', 'if', 'he', 'defending', 'Suarez', 'scouse', 'attack', 'Kandol20', 'RT', 'on', 'POTNOODLEFRINGE', 'Jews', 'the', 'defend', 'Hitlers', 'again', 'a']
# ['Nigger', "I'm", 'like', 'not', 'racist', 'fucking', 'Be', 'White', 'Mario', 'House', 'literally', 'people', 'Trap', 'you']
# ['tcot', 'it', 'antiWhite', 'tgdn', 'timeisnow', 'stop', 'terrorism', '2', 'Genocide', 'and', 'Genocide', '-', 'WR', 'White', 'White', 'Rape', 'iO24dhkI8Y', 'on', 't', 'co', 'Black', 'White', 'http']
# ['B7ZeNwRswu', 't', 'co', 'http', 'Power', 'White', 'i_like_cheese12']
# ['down', 'you', 'aristocunts', 'get', 'like', 'these', 'grafghost', 'notch', "don't"]
# ['white', 'etc', 'upset', 'men', 'pretty', 'me', 'women', 'rape', 'evil', 'am', 'man', 'Let', 'Equal', 'pay', 'Hurr', '1970', 'us', 'vote', '2015', 'durr', '1913', 'men', 'tweetlikeafeminist', 'am']
# ['years', 'ago', 'that', '60', 'over', 'happened', 'things', 'resentful', 'over', "I'm", 'still', 'only', 'to', 'to', 'Holocaust', 'the', 'one', 'get', 'here', 'need', 'the', 'around', 'allowed', 'be', 'Jews', 'The']
# ['marxism', 'racism', 'dK0GUbCb8y', 'PLANNED', 'immigration', 't', 'europe', 'http', 'race', 'co', 'next', 'WHITEGENOCIDE', 'America', 'IS', 'to', 'fallen', 'has', 'LONDON']
# ['problem', 'fucking', 'muslims', "what's", 'ARE', 'fucking', 'your', 'they', 'Jamika_jasmine']
# ['heckmonwyke', 'with', 'impunity', 'kill', 'they', 'Yanks', 'like', 'the', 'The', 'Jews', 'are']
# ['hatecrime', 'USA', 'HGnTWTsv3M', 'America', 'Genocide', 'PARIS', 'SWEDEN', 'racism', 't', 'White', 'EUROPE', 'co', 'http', 'race', 'WAR', 'LONDON', 'THE', 'IN', '-', 'FROM', 'PHOTOS']
# ['fucking', 'pedophile', 'bitch', 'little', 'botdfmusic', 'a', "you're"]
# ['cunt', 'An', 'bigger', 'LCFC', 'skysarahjane', 'even']
# ['2', 'of', 'laurenvonhuff', 'WW', 'cause', 'Ginn', 'the', 'Jews', 'obviously', 'the', "we're", 'Mc', 'JM', 'Colin']
# ['H', 'Xz', 'QP', '5FFx0OvLK8', 't', 'https', 'whitegenocide', 'NRx', 'for', 'https', 'co', 't', 'co', 'more', 'Germany', 'arab', 'RT', 'african', 'Thug_Violence', '000', 'heading', '600', 'invaders']
# ['KRewss7lUC', 'https', 't', 'Emulate', 'Zones', 'Israel', 'co', 'Genocide', 'White', 'Free', 'Genocide', 'so', 'Genocide', 'Misce', 'racist', 'promoting', 'genocidal', 'it', 'Sensible', 'is', 'is']
# ['Jews', 'can', 'somehow', 'Pavlich', 'on', 'the', 'this', 'blamed', 'be', 'Katie']
# ['eqnYqexq4G', 't', 'co', 'Palestinians', 'crucify', 'paper', 'http', "Adelson's", 'In', 'man', "Bibi's", 'Jews', 'RT', 'the', 'helping', 'bradleyburston', 'says', 'Pope']
# ['ocra', 'tcot', 'Jews', 'to', 'the', 'did', 'same', 'the', 'thing', 'Nazis', 'Teahadists', 'carefully', 'Terrorists', 'Teabaggers', '_Nightmare', 'Notice', 'RT', 'USMC', 'language', 'the']
# ['poor', 'nation', 'making', 'them', 'this', 'the', 'are', 'They', 'that', 'Call', 'who', 'people', 'not', 'undocumented', 'Democrat', 'are', 'illegals', 'do', 'voters', 'really', 'just', 'Please', 'call']
# ['Right', 'UGF', '2lwmWFl', 'cuckservative', 'On', 'Whites', 'https', 'Genocide', 'Children', 't', 'White', 'Alt', 'Onto', 'War', 'co', 'Fetish', 'Cuckold', 'Pushing', 'Interracial', 'Nickelodeon']
# ['empathy', 'feign', 'to', 'trying', 'incorrectly', 'cunt', 'chick', 'Probably', 'was', 'it', 'sounds', 'retarded', 'feminist', 'some', 'invented', 'like', 'by', 'Day', 'Mens', 'International', 'some']
# ['dangerous', 'damn', 'so', 'Jews', 'are', 'why', 'the', 'Protect', 'Politics', 'Arm', 'Peach', 'And']
# ['cuntery', 'of', 'I', 'All', 'hilighting', 'a', 'see', 'bit', 'that', 'me', 'is', 'Mary_Flashlight', 'jillsmo', 'victimhood', 'is', 'What']
# ['asshole', 'new', 'feminists', 'a', 'ripping', "wasn't", 'faggot', 'I', 'Twitter', 'love', 'it', 'on', 'SMABSO', 'mare_frigoris1', 'Meteoryan', 'Too', 'bad']
# ['anime-themed', 'his', 'Prophet', 'laughing', 'all', 'of', 'you', 'body', 'pillow', 'now', 'right', 'at', 'Japanese', 'fucking', 'some', 'think', 'right', 'Just', 'now', 'Khorosani', 'is']
# ['dick', 'not', 'niggers', 'for', 'shit', "ain't", 'even', 'moon', 'shoot', 'my', 'these', 'all', 'and', 'every', 'the', 'Jews', 'spic', 'kill', 'Returns', 'Spectre']
# ['spiritual', 'one', 'a', 'as', 'as', 'well', 'land', 'to', 'a', 'the', 'have', 'historical', 'Jews', 'Teilo', 'link', 'the', 'but', 'Bryn']
# ['Zebra', 'Yami', 'The', 'SUCK', 'DICK', 'BABY', 'OFF', 'THE', 'JEWS', 'HOW', 'ABOUT', 'TEACH', 'RT', 'HIM', 'Quatroking']
# ["you're", 'and', 'test', 'not', '2morrow', 'a', 'got', "bf's", 'load', 'after', "I'm", 'worth', 'my', 'of', 'done', "what's", 'cunt', 'left', 'Mercedes', 'The', 'Typing', 'Panda', 'svuceline', 'XXX', 'night', 'kk']
# ['f', 'cuz', 'a', 'few', 'more', 'drinks', 'starts', 'blaming', 'better', 'and', 'he', 'Jews', 'the', 'for', 'He', 'drinking', 'Democrats', 'stop', 'Boehner', 'John', 'shutdown', 'blames']
# ['b', 'Jews', 'would', 'the', 'ancient', 'people', 'of', 'that', 'His', 'Scotland', 'humiliation', 'promised', 'conversion', 'amp', 'prayer', 'kept', 'the', 'of', 'were', 'RT', 'sivartwright', 'in', 'Days']
# ['Adolf', 'Hitler', 'them', '-', 'killed', 'few', 'when', 'But', 'left', 'I', 'reason', 'why', 'I', 'for', 'all', 'a', 'Jews', 'I', 'them', 'the', 'the', 'to', 'show', 'live', 'kill', 'you', 'can', 'RT', 'I', 'Januzaj_Daily']
# ['slut', 'RT', 'Goat', 'rapekin', 'rabbit_isdead', 'Unburnt', 'stop', 'being', 'a', 'such']
# ['ht', 'Jews', 'Exterminate', 'Convinced', 'Palestinians', 'Hitler', 'Who', 'the', 'to', 'It', 'the', 'Was', 'Netanyahu', 'Claims', 'joke', 'RT', 'adamjohnsonNYC', "Israel's", 'not', 'this', 'is', 'a']
# ['Bible', 'Lad', 'Ji', 'The', 'and', 'leaving', 'on', 'Jews', 'ever', 'was', 'free', 'a', 'the', 'Moses', 'Egypt', 'broke', 'transfer', 'White', 'Schofield93', 'story', 'transfer', 'Jim', 'first', 'Luke', 'RT', 'The']
# ['m02b6bgJNo', 't', 'co', 'they', 'that', 'http', "didn't", 'on', 'Auschwitz', 'to', 'trains', "shouldn't", 'of', 'have', 'Why', 'think', 'the', 'gotten', 'RT', 'just', 'Jews', 'jbarro', 'Oh', 'the', 'wow']
# ['antiwhites', 'whitegenocide', 'right2life', '4', 'have', 'Whites', 'Whites', 'self', 'determination', 'law', 'say', 'by', 'created', 'the', 'is', 'within', 'society', 'saying', 'without', 'Goes']
# ['15wKhji', 'INJ', 'not', 'blood', 't', 'https', 'has', 'brain', 'co', 'genetic', 'that', 'the', 'to', 'terrorists', 'Jews', 'the', 'the', 'a', 'palestinian', 'is', 'in', 'of', 'supporter', 'hate', 'nazi', 'this']
# ['blood', 'shall', 'red', 'Euphrates', 'crucify', 'with', 'American', 'We', 'and', 'turn', 'the', 'of', 'Jews', 'the', 'Obama', 'RT', 'Oh', 'slave', 'Somali', 'you', 'Muhajir']
# ['U8APo5zLCt', 't', 'https', 'Of', 'Traitors', 'California4Trump', 'Cards', 'co', 'House', 'Hang', 'tranie', 'reptilian', 'whiteGenocide', 'Tranie', 'or', 'pacificbear7', 'RT', 'a']
# ['provoked', 'Obongo', 'mass', 'easily', 'to', 'the', 'Blacks', 'in', 'is', 'friend', 'no', 'have', 'excuse', 'Hitler', 'was', 'as', 'USA', 'used', 'Jews', 'the', 'Maydn', 'but', 'the', 'Jewish', 'mikekeyes35']
# ['Christie', 'Barbara', '-', 'fucking', 'moron', 'video', 'Susan', 'to', 'Sandra', 'Helena39', "i'm", 'evidence', 'christe4', 'going', "i'm", 'because', 'ignore', 'Sarandon', 'a']
# ['off', 'me', 'piss', 'so', 'tag', 'basically', 'Lives', 'hash', 'White', 'Lives', 'the', 'use', 'Matter', 'if', 'Black', "you're", 'you', 'undermining', 'Matter', 'you']
# ['Q5M2EA27', 'Zb', 't', 'https', 'CHILDREN', 'MY', 'co', 'RAPE', 'nI', 'n', 'WANT', 'IMMIGRANTS', 'ITS', 'TO', 'TRUE']
# ['Multicultural', 'Diversity', 'On', 'it', 'Whites', 'to', 'http', 'all', 'stop', 'War', 'and', 'William1975', 'put', 'it', 'a', 'RT', 'to', 'us', 'to', 'of', 'Genocide', 'up', 'Andy', 'real', 'White', 'is', 'is']
# ['they', 'want', 'do', 'whatever', 'Jews', 'the', 'Rockland', 'RT', 'Gerry', "let's", 'OM']
# ['cunt', 'Post', 'what', 'Bristol', 'a']
# ['lynched', 'fucking', "she'd", 'and', 'gamers', 'crossed', 'gamers', 'black', 'that', 'street', 'of', 'thing', 'with', 'Replace', 'word', 'get', 'the', 'the', 'in', 'because', 'Zennistrad', 'people']
# ['vvihA0uxP1', 'slaves', 'into', 't', 'co', 'us', 'turned', 'have', 'Knight1488', 'http', 'Jews', 'The', 'RT', 'White']
# ['REg5j1GVi2', 'https', 't', 'La', 'heath_houston', 'Bitchesthe', 'co', 'Twitter', 'Sp', 'Ed', 'Teacher', 'Tweets', 'Lucy', 'Fur', 'can', 'Cat', 'use', 'thinks', 'cats', 'person', 'who', 'the', 'sez']
# ['for', 'money', 'run', 'Chinkos', 'and', 'their', 'a', 'Germans', 'coordinated', 'we', 'Jews', 'the', 'give', 'will', 'we', 'properly', 'Igbos', 'can', 'be', 'If']
# ["nazi's", 'feminist', 'twatter', 'of', 'the', 'to', 'home', 'Welcome']
# ['s4J4B43CqF', 'happen', 't', 'https', 'to', 'EVER', 'co', 'ever', "antiwhite's", 'Genocide', 'of', 'thing', 'White', 'worst', 'program', 'the', 'absolutely', 'the', 'but', 'is', 'evil', 'Slavery', 'is']
# ['catching', 'So', 'anti-Semitism', 'are', '1930s', 'targeted', 'the', 'just', 'Muslims', 'Europe', 'in', 'Jews', 'only', 'in', 'the', 'There', 'Arabs', 'RT', 'Akyolin', 'any', 'English', 'hardly', 'were']
# ['fuckwits', 'hardmen', 'wannabe', 'racist', 'cunts', 'head', 'of', 'pack', 'bottle', 'stuk', 'ova', 'that', 'shud', 'fella', 'av', 'ynfa_thehub', 'the']
# ['for', 'suis', "'Je", "Charlie'", 'aamer_rahman', 'RT', 'Lives', 'Matter', 'basically', 'White', 'French', 'is']
# ['Suka', '4', 'Luv', 'Pussy', 'Sum', 'Niggas', 'Charco', 'Ugly', 'Is', 'Ya', 'Givinn', 'Bitch', 'Ugly', '2', 'Tatted', 'Mean', 'boricuamorena27', 'shawtaedoowop', 'Brett_Brewski', 'Hope', 'Im', 'That']
# ['israelis', 'them', 'But', 'HATE', 'tells', 'do', 'respect', 'I', 'not', 'to', 'me', 'do', 'religion', 'My', 'Jews', 'I', 'the', 'hate']
# ['Deed', 'Is', 'it', 'with', 'Bible', 'Israel', 'Jews', 'Belongs', 'In', 'The', 'Live', 'The', 'cbecker55373', 'RT', 'the', 'to', 'JCC', 'of', 'Watch', 'Land', 'The']
# ['Kwcvq8rImS', 't', 'https', 'SPLC', 'co', 'The', '-', 'racist', 'Being', 'RT', 'Genocide', 'against', 'Trump', 'White', 'Hat', 'is']
# ['khlabLcFcO', 't', 'https', 'Lives', 'thug', 'black', 'White', 'co', 'and', 'POS', 'Matter', 'by', 'murdered', 'this', 'raped', 'was', 'Blackburn', 'RT', 'Carter137', 'Amanda']
# ['6MTG2QEP', 'TK', 'wrongfullyconvicted', 'https', 't', 'Feminism', 'co', 'antifeminism', 'antifeminist', 'Against', 'alienation', 'familycourt', 'Women', 'LOGIC', 'Fascism', 'Fem']
# ['of', 'the', 'Jews', 'fairly', 'treating', 'the', 'because', 'Macron', 'Coelesyria', 'in', 'Ptolemy', 'taken', 'Phoenicia', 'had', 'lead', 'amp', 'the', 'called', 'of', 'commander-in-chief']
# ['je', 'we', 'so', 'long', 'the', 'all', 'hate', 'son', 'its', 'agree', 'lets', 'a', 'have', 'no', 'just', 'cant', 'God', 'and', 'saying', 'Muslims', 'Jesus', 'God', 'is', 'me', 'RT', 'iamhamdi1', 'telling', 'Christians']
# ['cunts', 'all', '7', 'of', 'year', 'old', 'than', 'my', 'fuck', 'you', 'they', 'neice', 'do', 'than', 'smarter', 'it', 'have', 'think', 'actually', 'note', 'is', 'side', 'worse', 'paris', 'mizzou', 'in', 'you', 'a', 'you']
# ['change', 'demographic', 'whitegenocide', 'normal', 'is', 'hate', 'propaganda', 'masters', 'of', 'war', 'love', 'say', 'peace', 'antiwhites', 'is', 'is']
# ['whitegenocide', 'c', 'do', 'less', 'will', 'our', 'and', 'countries', 'self-determination', 'sovereignty', 'own', 'with', 'Nothing', 'RT', 'full', 'Trainspotter001', 'require', 'Whites']
# ['5RfepLWjAq', 'NFrIi8WU', 't', 'https', 'co', 'https', 'Dr', 't', 'co', 'Marching', 'Slaughter', 'Jews', 'Drill', 'Algerian', 'and', 'Skin', 'the', 'Army', 'Reports', 'Kill', 'RT', 'MEMRI']
# ['old', 'uncircumsized', 'geezer', 'the', 'kerry', 'or', 'john', 'jews', 'where', 'obama', 'part', 'refers', 'to', 'as', 'state', 'mule', 'islam', 'that', 'the', 'of', 'like', 'i']
# ['svN4ysFWfy', 't', 'co', 'http', 'liberate', 'to', 'Jews', 'Palestine', 'from', 'the', 'RT', 'hand', 'together', 'hayatymarmar', 'in', 'hand']
# ['82UwqERM7s', 't', 'https', 'It', 'them', 'and', 'al-Husseini', 'co', 'Amin', 'religion', 'wherever', 'Haj', 'history', 'would', 'please', 'Jews', '1944', 'find', 'you', '1', 'the', 'God', 'Kill', 'March']
# ['-AdolfHitler-', 'them', 'killing', 'know', 'was', 'to', 'I', 'of', 'I', 'some', 'them', 'why', 'left', 'let', 'u', 'but', 'all', 'the', 'Jews', 'could', 'have', 'killed', 'I']
# ['mLIacpXCTn', 't', 'https', 'co', 'rot', 'companies', 'and', 'PC', 'mind', 'Navy', 'to', 'pander', 'Old', 'feminist', 'like', 'drivel', 'who', 'Fuck']
# ['cares', 'nobody', 'Jews', 'Actually', 'had', 'the', 'Hatred', 'Hitler', 'against', 'on', 'what', 'someone', 'was', 'like', 'is', 'you', 'enemies', 'about', 'to', 'hate', 'talking', 'born', 'be', 'of', 'Some']
# ['Power', 'Teridax_', 'White']
# ['Jews', 'the', 'of', '90', 'kill', 'RT', 'iowahawkblog', 'Iranian', 'someone', 'moderate', 'to', 'wants', 'only', 'who']
# ['t', 'https', 'Genocide', 'https', '5jPNP1FIWE', 'proud', 'White', 'oppose', 'Defend', 'mom', 't', 'Europe', 'co', 'Making', 'my', 'race', 'Shaking', 'white', 'RT', 'the', 'More', 'Electre', 'Is']
# ['hell', 'jail', 'and', 'to', 'needs', 'or', 'teacher', 'in', 'be', 'jews', 'in', 'kill', 'what', 'they', 'the', 'they', '-', 'Mayer', 'teach', "don't", 'hide', 'Avi', 'its']
# ['2fEEN1BD2h', 't', 'https', 'co', 'worst', 'Marcie', 'nFeminists', 'n', 'Bianco', 'account', 'the', 'are', 'Delete', 'your']
# ['kLxCl8X3Or', 't', 'https', 'CODEWORD', 'A', 'FOR', 'co', 'Genocide', 'understand', 'DIVERSITY', 'White', 'that', 'IS', 'They', 'diversity', 'this', 'over', 'year', 'obsess', 'GRAMM', "won't", 'Ys', 'The']
# ['ahis', 'amp', 'negligent', 'selfish', 'maybe', 'but', 'not', 'racist', 'racist', 'J_A_H_S', 'ashrouen', 'RT', 'whitelivesmatter', 'If', 'was', 'to', 'make', 'i', 'say', 'automatically', 'im']
# ['S3jAed8XQ7', 'https', 't', 'for', '1290', 'crimes', 'co', 'out', 'of', 'of', 'England', 'Jews', 'the', 'Longshanks', 'the', 'in', 'England', 'I', 'of', 'banished', 'or', 'the', 'Edward', 'Edward', 'King']
# ['worse', 'can', 'for', 'change', 'Biggest', 'lives', 'them', 'HRC', 'make', 'realize', 'stability', 'to', 'their', 'thing', 'anything', 'is', 'believe', 'Sanders', 'will', 'roseperson', 'people']
# ['they', 'only', 'if', 'knew', 'jews', 'Kanack', 'Sandu', 'Kan', 'welcome', 'Msosman7Osman', 'RT', 'the', 'arabs', 'Palestinian']
# ['Portugal', "German's", 'than', 'the', 'more', 'successful', 'Gags', 'RT', 'Jews', 'Footy', 'The', 'were', 'against']
# ['and', 'cried', 'foul', 'dead', 'corpse', 'its', 'raped', 'Then', 'it', 'killed', 'and', 'women', 'Chivalry', 'dead', 'is']
# ['not', 'poison', "I'm", 'your', 'taking', 'from', 'me', 'jews', 'to', 'the']
# ['musicians', 'made', 'to', 'music', 'REAL', 'by', "Don't", 'REAL', 'Bob', 'be', 'Listen', 'bobatl', 'to', 'STUPID', 'theory', 'proof', 'fucking', 'my', 'that', 'retard', 'is', 'music', 'rap', 'makes', 'you', 'This']
# ['p', "man's", 'his', 'they', 'the', '4', 'sent', 'had', 'sight', 'until', 'received', 'that', 'amp', 'had', 'still', 'he', 'been', 'not', 'believe', 'did', 'The', 'blind', 'Jews', 'John', 'RT', 'Jesusfollowcom', '18', '9']
# ['sindrom', 'down', 'fukkin', 'and', 'retardad', 'a', 'evn', 'cunts', 'mor', 'bunch', 'who', 'r', 'me', 'im', 'of', 'den', 'all', 'flopyvalle', 'c', 'a', 'i', 'is']
# ['KKK', 'whitegenocide', 'and', 'Libtard', 'invariably', 'about', 'or', 'Christian', 'word', 'are', 'same', 'concerned', 'the', 'the', '60070', 'usually', 'use', 'People', 'who', 'FR', 'Gr8Darwinians']
# ['2', 'BBC', 'Victims', 'Professional', 'The', 'Jews']
# ['asshole', 'muslim', 'fucking', 'freedom', 'https', 'land', 'BIPR', 'co', '3JNeSn', 'to', 'RT', 'of', 'the', 'be', 'vito_ralph', 'IDF', 'Spokesperson', 'SE', '25A', 't', 'a']
# ['cCGTU3E9PI', 't', 'co', 'http', 'Amzf19', "It's", 'Gvn2day', 'White', 'destroying', 'hordes', 'people', 'Fux', 'and', 'the', 'Jews', 'proxy', 'pies_n_prophet', 'their', 'No']
# ['spread', 'and', 'disease', 'Of', 'create', 'Cleric', 'lo', 'to', 'great', 'are', 'Islamic', 'http', 'Geller', 'irony', 'doctors', 'RT', 'the', 'Jews', 'paid', 'Jews', 'course', 'Pamela', 'the', 'is']
# ['they', 'ass', 'can', 'after', 'They', 'conversation', 'hold', 'and', 'filthiest', 'feminists', 'cum', 'a', 'sluts', 'the', 'their', 'in', 'fuck', 'are', 'you', 'to', 'I', 'like']
# ['Portgal', '2rNR2I1ZoU', 'fitnafake', 'revol', 't', 'every', 'co', 'them', 'http', 'on', 'islamic', 'in', 'ride', 'jews', 'jews', 'the', 'Donkeys', 'Belgium', 'shias', 'the', 'of', 'the', 'the', 'are']
# ['t', 'treason', 'survive', 'within', 'Pegida', 'from', 'cannot', 'But', 'Genocide', 'Cicero', 'it', 'http', 'nation', 'UKIP', 'can', 'White', 'A', 'survive', 'BNP', 'Lieb', 'fools', 'RT', 'BN', 'its']
# ['Pr', 't', 'co', 'Palestinians', 'http', 'with', 'self-hating', 'as', 'and', 'Jews', 'want', 'peace', 'humanity', 'RT', 'love', 'charlesfrith', 'dismiss', 'to', 'Zionists', 'like', 'the', 'Jews', 'who']
# ['ARE', 'JEWS', 'WE', 'THE', 'RELATIONS', 'POWERFUL', 'HOW', 'about', "isn't", 'like', 'POWER', 'about', "it's", 'RACE', 'And', 'Cou', 'Dam', 'RT', 'racism', "y'know", 'ALL', 'KNOW', 'Because']
# ['Wira', 'Obama', 'Perkasa', 'Barack', 'Gaza', 'Palestine', 'Save', 'Free', 'Allah', 'Jews', 'RT', 'Fahmiid', 'Israel', 'reason', 'the', 'Irwan', 'curse', 'cruelty', "world's", 'This', 'one', 'the', 'is', 'is']
# ['Majnoona', 'Terrina', 'with', "I'm", 'fact', 'Joseph', 'on', 'committee', 'steering', 'Is', 'Genocide', 'In', 'the', 'White', 'I', 'strongly', 'support', 'RT', 'Vegan']
# ['LMFAO', 'liar', 'fucking', 'what', "didnt'", 'it', 'RT', 'a', 'jews', 'deserve', 'Snepback', 'KD', 'literally', 'the', 'that', 'telling', 'me', 'is']
# ['Israel', 'themselves', 'all', 'all', 'Goyim', 'to', 'have', 'races', 'Planet', 'of', 'EARTH', 'kill', 'understand', 'to', 'made', 'to', 'the', 'to', 'Jews', 'have', 'mean', 'They', 'be', 'Steve66581312']
# ['SMyPODy', 'Ofh', 'PLEP', '5xuKAg', 't', 'https', 'co', 'https', 't', 'co', 'attack', 'Jews', 'they', 'Hebdo', 'yes', 'on', 'the', 'blaming', 'are', 'RT', 'Yair_Rosenberg', 'Charlie', 'already', 'the', 'Why']
# ['for', 'Jews', 'diversification', 'the', "I'm", 'it', 'to', 'not', 'list', 'bringing', 'Sixty', 'Highlands', 'are', 'my', 'of', 'on', 'Scottish', 'the', 'top', 'the', 'Richard']
# ['W', 'so', 'can', 'fight', 'account', 'second', 'help', 'and', 'you', 'a', 'about', 'create', 'are', 'RT', 'career', 'worried', 'genophilia', 'anonymous', 'name', 'real', 'under', 'If', 'your', 'tweet', 'you']
# ['symptoms-unlike', 'me', 'can', 'They', 'anti-PC', 'reacquire', 'Smart', 'it', 'to', 'identify', 'are', 'only', 'vacuum', 'rhetoric', 'The', 'Jews', 'politics', 'using', 'Western', 'in', 'power', 'Huge']
# ['tyrabanks', 'Newspaper', 'blog', 'Jews', 'Great', 'run', 'the', 'the', 'on', 'how', 'being', 'anti-Semite', 'an', 'do', 'to', 'with', 'everything', 'had', 'censorship', 'you', 'amanialkhat', 'the']
# ['Ce8vWL1Vhb', 't', 'https', 'co', 'Jews', 'exposes', 'Fischer', 'Chess', 'ever', 'Genius', 'mind', 'the', 'Also', 'Bobby', 'RT', 'Greatest', 'Saleena_1']
# ['dignity', 'for', 'his', 'cum', 'ass', 'of', 'full', 'I', 'an', 'traded', 'some', 'just', 'guy']
# ['VVh30', 'Hwz', 'Ip', 'https', 't', 'co', 'That', 'Wall', 'Build', 'would', 'it', 'seem', 'too', 'Genocide', 'White', 'want', 'gookers', 'Damn']
# ['snapchat', 'of', 'Power', 'instead', 'White', 'things', 'racist', 'can', 'tweet', 'I', 'you', 'Hard', 'Raging', 'Phrat', 'now']
# ['jews', 'for', 'hatred', 'jews', 'the', 'Y', 'cunt', 'Hey', 'Geller', 'Pamela', 'lynchlyons1', 'the']
# ['whitegenocide', 'eugenicists', 'want', 'insane', 'are', 'who', 'They', 'B', 'as', 'inferior', 'is', 'is', 'A', 'your', 'race', 'race-mixing', 'better', 'because', 'is', 'say', 'antiwhites']
# ['Qo5srmhq', 'Cb', 'https', 't', 'leaving', 'ones', 'co', 'real', 'are', 'than', 'the', 'feminism', 'women', 'why', 'this', 'less', 'loses', 'is', 'feminist', 'shit', 'cunt', 'brailes', 'her', 'evil', 'so', 'some']
# ['Israel', 'was', 'and', 'how', 'Jews', "that's", 'to', 'formed', 'the', 'it', 'gave', 'land', 'owned', 'was', 'the', 'it', 'and', 'British', 'Holmesss', 'Maxx']
# ['t', 'islamistheproblem', 'whitegenocide', 'pjnet', '5xK1U6P5K1', 'https', 'Demonstrators', 'PEGIDA', 'https', 't', 'Leads', 'co', 'Patriot', 'Aodh', 'Great', 'RT', 'Lady', 'Aussie']
# ['at', 'Sarah', 'laughed', 'are', 'this', 'feminists', 'why', 'Mafia', 'is', 'Bills', 'Bills_Chick']
# ['fjIVjiyt75', 't', 'co', 'rainbows', 'save', 'http', 'the', 'Jews', 'but', 'the', 'Kill']
# ['sLIRBbHtOy', 'https', 't', 'co', 'cunt', 'hypocrite', 'fucking', 'notch', 'for', 'bashing', 'RT', 'a', 'atak_jak', 'look', 'the', 'Oh', 'guy', 'is', 'using']
# ['shameless', 'injeel', 'and', 'Tawrat', 'and', 'sin', 'Messiah', 'by', 'the', 'Jews', 'Catholic', 'to', 'Christians', 'the', 'Gospel', 'Zionism', 'the', 'false', 'rule', 'lobby', 'corrupted', 'sin', 'gay', 'The']
# ['fFzwZS2ATf', 'whitegenocide', 'https', 'trump', 't', 'https', 'co', 'White', 'Aodh', 'Belgian', 'Too', 'Govt', 'Dept', 'RT', 'Lady', 'Flemish', 'of', 'Culture', 'Official', 'Culture', 'is']
# ['A', 'HJNQB', 'Yvcq', 'Nisman', 't', 'co', 'Argentina', 'for', 'prosecutor', 'Alberto', 'http', 'hero', '-', 'no', 'Jews', 'slain', 'or', 'the', 'is', 'Why']
# ['fucking', 'bitch', 'shit', 'piece', 'VOTER', 'of', 'of', 'USA', 'FRAUD', 'CUNT', 'known', 'gonna', 'as', 'the', 'face', 'the', 'in', 'be', 'forever', 'are', 'an', 'You', 'unpatriotic', 'rlange9', 'are', 'You']
# ["pandora's", 'all', 'them', 'and', 'like', 'box', 'opened', 'in', 'let', 'to', 'british', 'the', 'lot', 'until', 'uk', 'belongs', 'you', 'jews', 'to', 'belongs', 'ed_miliband', 'lucianaberger', 'the', 'israel']
# ['YOU', 'DAMN', 'FUCKING', 'RT', 'NIGGERS', 'COME', 'Louie82Y', 'ON']
# ['ever', 'so', 'muslims', 'after', 'that', 'give', 'happily', 'dont', 'know', 'living', 'killing', 'and', 'all', 'we', 'Muslims', 'that', 'jews', 'turn', 'muslims', 'Sabbag', 'would', 'are', 'Doug', 'on', 'the']
# ['Q2n', 'Ej', 'BQ', 'Bn', 't', 'https', 'co', 'Immigration', 'Mass', 'grows', 'German', 'Genocide', 'RT', 'Trainspotter001', 'of', 'White', 'Genocide', 'creeping', 'of', 'people', 'the', 'Awareness', 'is']
# ['for', 'canard', 'Jews', 'thought', 'was', 'the', 'an', 'antisemitic', 'I', 'just', 'good', "What's", 'UK', 'News', 'Jewish']
# ['L32Rb82Yq9', 't', 'Magazine', 'Tablet', 'co', 'http', 'Work', 'to', 'Sunday', '9', '9', 'am', 'Friday', 'Not', 'Analysts', 'to', 'pm', 'Allowed', 'Junior', 'Jews', 'Goldman', 'from', 'the', 'Taking', 'page', 'a']
# ['tVdTLABvW4', 'mtwitte48969127', 't', 'amp', 'for', 'asking', 'from', "isn't", 'co', 'on', 'pic', 'her', 'it', 'http', 'What', 'cum', 'adezero', 'if', 'asked', 'can', 'dougie89460283', 'Creep', 'u', 'u']
# ['toomanyblacks', 'VII', 'Wars', 'Boycott', 'Genocide', 'Wars', 'Star', 'White', 'boycott', 'on', 'Star', 'what', 'the', 'opinion', 'your', 'realDonaldTrump', 'is']
# ['everyday', 'd', 'that', 'no', 'you', 'holocaust', 'we', 'the', 'remember', 'stating', 'asshole', 'and', 'it', 'jews', 'over', 'get', 'some', 'then', 'just', 'RT', 'should', 'complainstnople', 'how', 'the']
# ['elqoF3Jn0g', 'tcot', 'blacklivesmatter', 'jericho', 'cuckservative', 'whitelivesmatter', 't', 'pjnet', 'too', 'co', 'http', 'representation', 'deserve', 'White', 'people']
# ['trans-coloured-genderfluid-headmates', 'a', 'container', 'thought', 'I', 'were', 'woman', 'you', 'a', 'evilfeminist', "You're"]
# ['c', 't', 'https', 'Hackney', 'MPS', 'N16', 'by', 'at', 'arrested', 'pedestrians', 'Jews', 'in', 'the', 'Kill', 'Jewish', 'shouting', 'Jews', 'ing', 'RT', 'Shomrim', 'Male', 'F', 'Akbar', 'Allahu']
# ['niggggaaaaa', 'alllll', 'they', 'work', 'Lipz', 'Jews', 'give', 'me', 'stress', 'at', 'are', 'the', 'tomorrow', 'gonna', 'Dada', 'Don']
# ['out', 'cock', 'take', 'and', 'techno', 'Put', 'your', 'some', 'on']
# ['Soun', 'Aviv', 'rocketed', 'Tel', 'a', 'who', 'praised', 'dictator', 'memes', 'amp', 'neo-Nazi', 'has', '48', 'Trump', 'hours', 'Yair_Rosenberg', 'RT', 'tweeting', 'So', 'defending', 'over', 'last', 'the']
# ['Hitler', 'them', 'Kudos', 'killed', 'I', 'why', 'to', 'I', 'the', 'kept', 'some', 'world', 'of', 'the', 'all', 'but', 'show', 'world', 'the', 'Jews', 'I', 'would', 'killed', 'great', 'Hither', 'said', 'The', 'have']
# ['mspiggy', 'yo', 'must', 'be', 'pig', 'wife', 'bitch', 'new', 'Denise', 'the', 'and', 'she', 'who', 'ass', 'shit', 'looking', 'look', 'frog', 'the', 'Kermit', 'yo', 'and', 'like', 'arms', 'hocks', 'michaelsmith', 'ham']
# ['nevertrump', 'me', 'Blacks', 'than', 'more', 'the', 'Hispanics', 'Jews', 'the', 'the', 'women', 'respects', 'Nobody']
# ['RT', 'lost', 'GTFOH', 'Nlight', 'Kobe', 'Clippers', 'Truth', 'losing', 'fucking', 'nigger', 'do', 'Lakers', 'to', 'Clippers', 'do', 'have', 'the', 'with', 'the', 'RT', 'fuck', 'Gawd', 'Wut', 'Coon', 'the', 'you']
# ['doubly', 'so', 'yourself', 'it', 'If', 'edited', 'you', 'idiot', 'an', 'gb_ball', "You're"]
# ['hV0Anehi80', "they're", 't', 'That', 'co', 'ppl', 'explains', 'white', 'http', 'cos', 'white', 'White', 'lot', 'attack', 'Lives', 'a', 'to', 'Matter', 'okay', "it's", 'So', 'tonieeB_']
# ['FZL', 'htt', '0L', 'Sia', 'YK', 'for', 'treason', 'NRx', 'whitegenocide', 't', 'co', 'collapse', 'to', 'about', 'http', 'system', 'tried', 'leaders', 'European', 'RT', 'Thug_Violence', 'should', 'be']
# ['1KZM6x', 'MBUQ', 'whitegenocide', 't', 'https', 'co', 'we', 'need', 'why', 'of', 'examples', 'RT', 'guys', 'prime', 'are', 'Thalwen', 'These']
# ['t\xc3', 'like', 'politicians', 'same', 'when', 'the', 'cunts', "don't", 'whiny', 'you', 'turn', "Americans'", 'thinking', 'into', "I've", 'noticed', 'progressive', 'Jim', 'RT', 'lot', 'Norton', 'of', "'free", 'a']
# ['detect', 'hard', 'to', 'rabid', 'and', 'are', 'genocide', 'the', 'because', 'outlaw', 'religion', 'hate', 'thing', 'PC', 'a', 'non', 'of', 'cmdeb', 'the']
# ['https\xc3', 'money', "man's", 'not', 'I', 'to', 'a', 'thought', 'could', 'know', 'supposed', 'need', 'Feminists', 'were', 'diggers', 'I', 'Past', "didn't", 'Feminists', 'that', 'The', 'be', 'gold', 'From', 'RT', 'Jack']
# ['being', 'him', 'Romans', 'Jews', 'crucified', 'responsible', 'bible', 'The', 'the', 'the', 'to', 'Except', 'archaeology', 'support', 'or', 'history', 'there', 'no', 'is', 'thelittlepakeha']
# ['Torah', 'that', 'of', 'the', 'there', 'said', 'a', 'called', 'Having', 'If', 'Jesus', 'section', 'not', 'is', 'kill', 'did', 'Jews', 'state', 'to', 'the', 'that', 'RT', 'Ian', 'want', 'Karmel', 'I', 'just', 'clearly']
# ['White', 'extermination', 'clear', 'vile', 'too', 'intentions', 'only', 'are', 'bro', "shouldn't", 'we', 'but', 'flooding', 'the', 'anyone', 'in', 'Jews', 'be', 'GBRVOICE', 'wrong', 'get', 'me', "Don't"]
# ['whitegenocide', 'propaganda', 'its', 'US', 'of', 'rights', 'bill', 'constitution', 'bypassing', 'the', 'under', 'of', 'discussion', 'the', 'slur', 'established', "privilege'", 'a', "'white", 'is']
# ['u2026', 'so', 'someone', 'much', "I've", '-', 'wanted', 'to', 'in', 'punch', "'", 'Terrorist', 'never', 'prick', 'Muslim', 'fucking', 'at', 'yet', 'RT', 'someone', 'heard', 'I', 'man', 'FFigureFBust', 'a', 'just', "'You"]
# ['and', 'whine', 'bitch', 'shillbots', 'neo-con', 'Runs', 'would', 'to', 'Who', 'respond', 'Just', 'would', 'but', 'with', 'hashtag', 'I', 'America', 'the', 'Jews', 'the', 'Buckley', 'IWF']
# ['pJQWO76oYP', 't', 'https', 'co', 'De-Segregation', 'and', 'Kids', 'Genocide', 'furthers', 'White', 'White', 'White', 'of', 'IS', 'people', 'protection', 'institutional', 'the', 'Segregation']
# ['wedding', 'feelings', '3-day', 'conflicted', 'have', 'Lebron', 'really', "James'", 'festivities', 'weekend', 'to', 'invited', 'this', 'Jews', 'the', 'I', 'bet']
# ['cunt', 'follow', 'suffocvtion', 'u', 'me']
# ['that', 'not', 'you', 'was', 'supposedly', 'feed', '911', 'did', 'caller', '1', 'from', 'the', 'the', '3', 'shot', 'check', 'cunt', 'dumb', 'christians', 'shot', 'never', 'He', 'you', 'Looney', 'Bodhi']
# ['rKEYHQvwDl', 'https', 't', 'co', 'incest', 'fossilized', 'violence', 'for', 'doctrine', 'becoz', 'so', '5', 'of', 'millennium', '1', 'its', 'hate', 'last', 'rightly', 'of', 'Religion', 'And']
# ['7H9rhq', 'BILS', 't', 'co', 'out', 'http', 'to', 'stink', 'crawled', 'place', 'the', 'up', 'muslim', 'maggot', 'La', 'Fucking', 'Donna', 'hyderabb', 'Rae1961', 'Jew_Pakistani']
# ['Israel', 'word', 'death', 'say', 'to', 'to', 'Islam', 'Jews', 'victory', 'death', 'to', 'the', 'America', 'to', 'great', 'death', 'God', 'is']
# ['terroristinchief', 'Islam', 'problem', 'disarming', 'Obama', 'the', 'make', 'us', 'victims', 'infidels', 'is', 'asshole', 'Muslim', 'fucking', 'You']
# ['terriblepeople', 'years', 'ago', 'jews', 'against', 'everything', 'the', 'started', 'who', 'the', 'people', 'Fck']
# ['s5QSQc', 'https', 't', 'like', 'Genocide', 'co', 'White', 'to', 'him', 'look', 'Every', 'child', 'Race', 'his', 'Ali', 'intelligent', 'Mixing', 'wants', 'on', 'RT', 'Fr3333dom', 'Muhammad', 'person']
# ['for', 'our', 'over', 'board', 'relationship', 'a', "That's", 'xoxpearlxoxyou', 'andieiamwhoiam', 'bit', 'angry', 'really', 'Cunt', 'kinda', '91Onc', 'wanna', 'talk', 'anaxing56789', 'seem']
# ['tits', 'fat', 'with', 'Spics']
# ['Geno', 'Right', 'authority', 'before', 'shark', 'all', 'our', 'White', 'losing', 'moral', 'jumped', 'has', 'the', 'order', 'it', 'liberal', 'RT', 'post-war', 'eyes', 'Trainspotter001', 'is', 'The']
# ['Je', 'pointing', 'the', 'are', 'finger', 'here', 'you', 'And', 'ruins', 'culture', 'and', 'Arab', 'terrorising', 'the', 'society', 'John', 'currently', 'world', 'RT', 'in', 'Wallace_au', 'is', 'Islam', 'is']
# ['cunt', 'smelly', 'feed', 'more', 'Man', 'mamma', 'LFC', 'juanmata8', 'Alx', 'little', 'filthy', 'rats', 'Go', 'Utd', 'inbred', 'you']
# ['qOhW7a5c7e', 't', "latino's", 'africans', 'co', 'adopted', 'This', 'all', 'http', 'my', 'and', 'Whites', 'to', 'asians', 'blacks', 'the', 'is', 'Arabs', 'all', 'To', 'the', 'Warning', 'Jews']
# ['https', 'white', 'It', 'our', 'marry', 'our', 'genetics', 'a', 'Pro', 'Genocide', 'to', 'White', 'White', 'duty', 'it', 'preserve', 'do', 'is', 'right', 'white', "you're", 'If', 'Caucasian', 'Allure', 'RT']
# ['lenadunham', 'that', 'time', 'one', 'raped', 'that', 'you', 'jerking', 'to', 'men', 'sister', 'maybe', 'your', "There's", 'no', 'off', 'you']
# ['antiJEWS', 'humanity', 'learn', 'will', 'stoodup', 'they', 'When', 'bcoz', 'against', 'Jews', 'they', 'what', 'the', 'RT', 'are', 'akuskizo', 'become', 'today', 'The', 'Germans']
# ['fDzQSnD2Xr', 'LGBTQIACTULHUBBQ', 'furrykin', 'https', 't', 'co', 'as', 'for', 'identify', 'normal', "don't", 'who', 'people', 'Feminist', 'vision']
# ['t', 'tcot', 'This', 'US', 'http', 'babies', 'UKIP', 'of', '30', 'Genocide', 'lt', 'lt', 'White', 'pop', 'amp', '10', 'prob', 'is', 'of', 'b', 'whites', 'will', 'Bureau', 'Lieb', 'RT', 'Census', 'BN', 'by', 'says', '2060']
# ...
# ['Is', 'Magic', 'Genocide', 'villainial', 'White']
# ['lUAk8E69f9', 'attack', 'https', "they're", 't', 'for', 'blaming', 'far-right', 'Jews', 'far-left', 'to', 'co', 'the', 'from', 'the', 'Nice', 'already', 'wondering', 'were', 'case', 'you', 'In']
# ['on', 'men', 'hate', 'to', 'gap', 'wage', 'use', 'KNK', 'feminists', 'excuse', 'Annie', 'an', 'just', 'is']
# ['vFUko5i9g5', 't', 'https', 'co', 'Lives', 'White', 'Does', 'Matter', 'mean', 'this']
# ['Bn6MlrGxky', 't', 'co', 's7PcUEtHJy', 'http', 't', 'co', '-', 'http', 'New', 'de', 'of', 'Bill', 'and', 'York', 'Jews', 'Blasio', 'the']
# ['Europe', 'Free', 'intolerance', 'and', 'woman', 'religion', 'hate', 'stuck', 'teeth', 'a', 'a', 'white', 'in', 'to', 'listen', 'then', 'dutch', 'of', 'rather', 'with', 'id', 'guy', 'a', 'Yasminaelx']
# ['R3yVUrWIdY', 't', 'https', 'filicide', 'co', 'with', 'via', 'nontherapeutic', 'impunity', 'abortions', 'End']
# ['mzy', 't', 'https', 'co', 'Islamic', 'State', 'the', 'Celebrated', 'Behind', 'The', '3', 'are', 'Part', 'ingridcarlqvist', 'of', 'RT', 'Imam', 'Sweden', 'Jews', 'The', 'by', 'out', 'is', 'the', 'Church']
# ['EPIDEMIC', 'IS', 'AN', 'RAPE', 'has', 'nFeminist', 'Statistics', 'crime', 'epidemic', 'dropped', 'nPeople', 'an', 'the', 'in', 'decades', 'show', 'past', 'is', 'sexual', 'Rape', 'Feminist']
# ['heaven', 'that', 'out', 'by', 'safe', 'provided', 'It', 'Empire', 'G0_NAWAZ_G0', 'Jews', 'Mujahid_e_Islam', 'mashraflondon', 'RT', 'thrown', 'was', 'Ottoman', 'who', 'the', '2', '2', 'were', 'the', '2']
# ['htt', 'ridicules', 'how', 'Jews', 'to', 'want', 'the', 'eradicate', 'K_M_C_90', 'more', 'jife1', 'who', 'Right', 'Arabs', 'Texas', 'Bowie', 'Eddie', 'Q', 'Skwirly', 'Wing', 'Jim', 'Palestinian601', 'RT']
# ['etmb8YHIaE', 't', 'co', 'http', 'for', 'blaming', 'finish', 'Jews', 'with', 'business', 'un', 'the', 'you', 'am', 'I']
# ['jews', 'and', 'blaming', 'it', 'killer', 'the', 'by', 'to', 'being', 'and', 'a', 'half', 'death', 'building', 'robot', 'beaten', "It's", 'like']
# ['Explain', 'die', 'escape', 'One', '6', 'allow', 'to', 'innocents', 'to', 'minute', 'to', 'Red', 'parts', 'Sea', 'million', 'God', 'Egypt', 'from', 'sits', 'allows', 'back', 'Jews', 'the', 'the', 'and', 'the', 'next']
# ['Jews', 'Like', 'the', 'before', 'so', 'never', 'when', 'mom', 'phone', 'or', 'was', 'R', 'died', 'erasing', 'find', 'to', 'rings', "mother's", 'The', '10', 'arrives', 'mom', 'My', 'only', 'be', 'will', 'You']
# ['t', 'save', 'http', 'Genocide', 'to', 'White', 'help', 'Europe', 'prevent', 'balls', 'Man_1488', 'beautiful', 'White', 'This', 'woman', 'Boss', 'RT', 'counting', 'on', 'White', 'men', 'with', 'real', 'is']
# ['together', 'stick', 'more', 'We', 'like', 'gotta', 'can', 'Jews', 'the', 'them', 'the', 'be', 'I', 'blacks', 'hear', 'say', 'gotta', 'Honeyb0000']
# ['twmk1', 'rights', 'out', 'them', 'Jews', 'singling', 'civilian', 'the', 'laws', 'of', '1933', 'April', '7', 'restricting', 'of', 'legally', 'Law', 'of', 'many', 'first', 'many', 'Civil', 'Service', 'The']
# ['1sQ', 'KYTP', 't', 'Behead', 'co', 'Jerusalem', 'Feed', 'Mujahideen', 'to', 'Jews', 'http', 'the', '-', 'the', 'Message', 'in', 'Jewish', 'releases', 'ISIS', 'BREAKING', 'video', 'RT', 'Conflicts']
# ['https\xc3', 'n', 'reeeeeee', 'it', 'responds', 'over', 'press', 'n', 'nintendo', 'gt', 'her', 'gt', 'friends', 'clique', 'the', 'her', 'of', 'joke', 'in', 'actually', 'feels', 'about', 'is', 'dumb', 'whore', 'RT', 'Doomskander', 'gt']
# ['subhanAllah', 'Somalia', 'of', 'midgan', 'Jews', 'the', 'are', 'someone', 'saying', 'how', 'is']
# ['gtamdfhYHs', 'Prejudiced', 'https', 't', 'co', 'Shouted', 'Who', 'Jews', 'Muslim', 'the', "Isn't", 'Kill', 'Hopes', 'Judge']
# ['Death', 'Eaters', 'UKIP', 'Debt', 'Genocide', 'Slavery', 'Op', 'Jihad', 'Rape', 'White', 'c8dcNQcmJJ', 'https', 't', 'co', 'People', 'Of', 'The', 'Genocide', 'Timeline', 'Of', 'The', 'Jewish', 'British']
# ['Man', 'Genocide', 'Twitter-etiquette', 'White', 'March', 'White', 'applies', 'to', 'I', 'literary', 'think', "don't", 'criticism', 'fool', 'ye', 'Bastard', 'One', 'olde', 'Sad', 'anti-White']
# ['40EnJ3Gx2', 't', 'co', 'where', 'Any', 'for', 'All', 'http', 'ISIS', 'Jews', 'Holland', 'Jihad', 'Ico', 'calls', 'Jews', 'Nature', 'of', 'flags', 'black', 'RT', 'Jews', 'The', 'the', 'the', 'of', 'death', 'wave', 'in']
# ['1hWX4g', 'Ih', 'RR', 't', 'co', 'H', 'and', 'night', 'man', 'came', 'http', 'to', 'Jesus', 'by', 'to', 'said', 'Nicodemus', 'This', 'Pharisees', 'ruler', 'There', 'Jews', 'of', 'the', 'a', 'of', 'named', 'the', 'man', 'was', 'a']
# ['bpvWX9J05p', 't', "they're", 'whitegenocide', 'co', 'genocide', 'http', 'RT', 'this', 'eyeslevel', 'complicit', 'bans', 'twitter', 'in', 'If']
# ['t', 'https', 'Democrats', 'for', 'turn', 'Israel', 'The', 'and', 'help', 'with', 'vote', 'Rotondo86', 'Rightist', 'around', 'GOP', 'then', 'The', 'to', 'the', 'Mike', 'always', 'run', 'Jews', 'in', 'RT']
# ['hypocricy', 'USA', 'was', 'they', 'wing', 'Sarah', 'ignored', 'Palin', 'are', 'largely', 'bc', 'right', 'rape', 'gets', 'incitement', 'to', 'tweets', 'amp', 'Hopkins', 'abusive', 'frequently', 'KT', 'LBC']
# ['A3eU7nmpWM', 't', 'A5H0KA', 'Karratti', 'Then', 'co', 'others', 'http', 'Paul', 'kill', 'Jews', 'Umeboshi', 'the', 'Chuck', 'gun', 'RT', 'used', 'Hitler', 'to', 'control']
# ['IVvarqUEeA', 't', 'https', 'co', 'tripe', 'for', 'and', 'for', 'rantzerker', 'Feminist', 'phrasing', 'evening', 'shows', 'the', 'the', 'are', 'double', 'show', 'this', 'Robin', 'Ceara', "Thursday's"]
# ['PLgboiJis4', 't', 'co', 'http', 'gone', 'same', 'been', 'since', "you've", 'the', 'been', 'Day', "hasn't", "Father's"]
# ['Whiteliesmatter', 'Whitelivesmatter', 'LMAOOOO', 'lmeZoDaB8S', 'D', 't', 'https', 'co', 'Ari', 'Thehate', 'Iam', 'Queen', 'Fetrick']
# ['dumbass', 'when', 'Since', 'games', 'played', 'DALLAS', "Melo's", 'fit', 'Rose', '49', '3', 'best', "He's", 'years', 'is', 'the', 'jackoff', 'past', 'fucking', 'idiot', 'MVP', '1tompenn']
# ['for', 'you', 'problem', 'I', 'have', 'news', 'more', 'putting', 'there', 'on', 'the', 'will', 'fix', 'think', 'regulations', 'You', 'on', 'Feminist', 'have', 'we', 'Kristof', 'guns', 'The', 'What', 'Nick']
# ['tcot', 'whitegenocide', 'maga', 'vampire', 'them', 'up', 'love', 'follow', 'trump', 'like', 'garlic', '2', 'discussion', 'stirs', 'but', 'destroy', 'to', 'antiwhites', 'infiltrate']
# ['hhSDtSZ1vc', 'Genocide', 'White', 't', 'and', 'co', 'http', "isn't", 'anyone', 'French', 'else', 'who', 'jews', 'for', 'France', 'Asians', 'for', 'Asia', 'the', 'Africans', 'for', 'the', 'the', 'Africa']
# ['begi', 'the', 'on', 'when', 'since', 'it', 'Jews', 'celebrating', 'have', 'when', 'Sabbath', 'Saturday', 'the', 'RT', 'katerinaaxo', 'to', 'ppl', 'been', 'call', "It's", 'me', 'so', 'Sunday', 'interesting']
# ['it', 'for', 'like', 'to', 'use', 'this', 'waiting', 'then', 'it', 'about', "they've", 'are', 'left', 'something', 'smug', 'far', 'been', 'rather', 'certain', 'Cuntona', 'the', 'almost', 'King']
# ['slATD4hafl', 't', "Hitler'", 'co', 'http', 'under', 'like', "'feel", 'Jews', 'the', 'children', "Berlusconi's"]
# ['tgx0VCphoU', 'https', 't', 'dateline', 'co', 'the', 'Check', 'SMART', 'FUCKING', 'RT', 'NEWSFLASH', 'Nero', 'REALLY', "I'M"]
# ['off', 'thursday', 'amp', 'friday', 'with', 'clutch', 'the', 'in', 'coming', 'jews', 'the', 'yo']
# ['Hate', 'Black', 'White', 'czruNrBfOg', 'https', 'WASTIKA', 'Christmas', 't', 'Store', 'White', 'Genocide', 'White', 'W', 'co', 'Flag', 'Confederate', 'ITEMS', 'Visit', 'EBAY', 'NAZI']
# ['Izcc9g', 'Yyaw', 't', 'co', 'Athens', 'http', '1939-1945', 'and', 'Resistance', 'Two-day', 'begins', 'RT', 'damomac', 'Europe', 'on', 'conference', 'in', 'the', 'Jews', 'in', 'today']
# ['t', 'somehow', '-', 'positivist', 'advanced', 'against', 'Daily', 'http', 'we', '-', 'moderns', 'are', 'that', 'Jews', 'Post', 'and', 'ICYMI', 'Lollardfish', 'RT', 'the', 'the', 'Crusades', 'notion']
# ['H4FX2ol9T7', 't', 'https', 'Again', 'Family', 'co', 'Make', 'Great', 'America', 'Trump', 'Genocide', 'NJ', 'White']
# ['MAWG', 'https', 'E1YvLIZQVG', 'Genocide', 'White', 'https', 't', 'co', 'more', '200', 'crimes', 'than', 'Aodh', '000', 'have', 'Refugees', 'RT', '2015', 'committed', 'Lady', 'in', 'Germany', 'alone']
# ['for', 'bday', "Rachel's", 'jews', 'the', 'and', 'meal', 'Cinema', 'with']
# ['martian_munk']
# ['KLP', 'Rachel', 'into', '-', 'commitment', 'SOOOO', 'The', 'are', 'Jew', 'RT', 'Jews', 'with', 'Hullfish', 'a', 'Nathan', 'I', 'want', 'you']
# ['imbeciles', 'or', 'cowards', 'society', 'of', 'because', 'jews', 'full', 'is', 'mentions', 'the', 'Nobody']
# ['some', 'time', 'feminist', 'mansplaining', 'to', 'have', 'literature', 'I', 'read', 'educate', "don't", "it's", 'called', 'you', 'G8T3R_NaTION']
# ['circumcise', 'All', 'Iknow', 'Cfunk', 'Jews', 'the', 'CM']
# ['blistering', 'Fucking', 'at', 'HD', 'Live', 'Rockpalast', 'Jam', 'The', 'arts', 'Sky']
# ['anni', 'Commanded', 'ar', 'do', 'too', 'n', 'to', 'for', 'demonizing', 'Christians', 'Zios', 'Jews', 'while', 'Islam', 'what', 'exactly', 'conceal', 'the', 'Evil', 'mlkstudios', 'RT', 'warrioroftrut']
# ['muslim', 'sioa', 'tcot', 'ha2ozRrtxa', 't', 'co', 'Palestinians', 'They', 'http', 'Slaughter', 'Jews', 'Must', 'the', 'Tells', 'Hamas']
# ['i8aZPvGfD9', 'RT', 'https', 't', 'palestinians', 'co', 'Jews', 'more', 'b4', 'tell', 'about', 'here', 'have', 'us', 'how', 'the', 'Nudnikit', 'always', 'Plz', 'been', 'Screed', 'Cmdr', '1D_KSA', 'Angry']
# ['Pn4utebUdD', 't', 'co', 'http', "'Jail", 'game', "Jews'", 'elementary', 'RT', 'kids', 'have', 'Anomaly100', 'the', 'been', 'Massachusetts', 'school', 'playing']
# ['xFe0DWVfUI', 't', 'co', 'http', 'Genophiles', 'Genocide', 'Genophilia', 'embrace', 'White', 'and', 'stop', 'Whites', 'RT', 'love_your_race', 'Unite', 'become']
# ['Genoc', 'for', 'codeword', 'Diversity', 'a', 'can', 'non-whites', 'it', 'White', 'Diversity', 'have', 'so', 'is', 'WRONG', 'billion', 'how', '6', 'is', 'RT', 'GREAT', 'then', 'If', 'Americans', 'Euro']
# ['regrets', 'It', "'Jesus", 'they', 'No', 'predicted', 'have', 'said', 'a', 'home', "'", 'Jews', 'mother', 'Chrizz', 'the', 'way', 'the', 'Chris', 'never', 'will', 'is', 'in', 'act', 'My', 'Mc']
# ['whiteguilt', 'Genocide', 'on', "I'm", 'White', 'Boo', 'twitter', 'you', 'heckling', 'Okay', 'line', 'suck', 'wait', 'was', 'that', 'funny', 'to', 'Oh', 'supposed', 'the', 'big', 'jimmy_dore', 'be', 'you']
# ['superbowl50', 'Whitelives', 'Beyonce', 'Racism', 'white', 'Matter', 'superbowl', 'the', 'at', 'dancers', 'There', '6', 'no', 'LSV', 'RT', 'are', 'Monte']
# ['etc', 'dick', 'qtpie', 'agenda', 'Yes', 'queer', 'push', 'do', 'the', 'reasons', 'feminist', 'meekstape', 'personal', 'are', 'those', 'you', 'you']
# ['Iyynly', 'TSJM', 't', 'co', 'rymk5B1KJq', 'cuckservative', 'NRx', 'Pegida', 'http', 'co', 't', 'Kelly', 'http', 'Genocide', 'to', 'Syrians', 'File', 'White', 'borders', 'opens', 'Govt', 'German']
# ['OAb190s6', 'Lo', 'https', 't', 'co', 'BITCH', 'GIBME', 'BLANKET']
# ['Guerrilla', 'Wobbitt', 'Rilla', 'Laughable', 'Mrs', 'baaahahaha', 'Jews', 'MEastQuagmire', 'was', 'Jesus', 'of', 'the', 'Yes', 'King', 'Assyrian', 'Anarch', 'RT', 'Voluntary']
# ['Rollins', 'Lou', 'someone', 'hate', 'whom', 'Now', 'it', 'means', 'the', 'Jews', 'Jews', 'hates', 'someone', 'to', 'used', "'Antisemite'", 'Mechanic', 'mean', 'Harmful', 'Gurdur', 'who']
# ['basically', 'a', 'with', 'slight', 'I', 'except', 'same', 'Jews', 'blame', 'to', 'the', 'the', 'because', 'its', 'sounds', 'eerily', 'Soparvaz', 'I', 'RT', 'similar', 'blame', 'Muslims', 'the', 'Tehran']
# ['bjovrDdiwK', 't', 'for', 'co', 'http', 'Jews', 'the', 'works', 'Iraqi', 'He', 'Suryani', 'anthonyfurey', 'yobynnad1127']
# ['day', 'hitler', 'celebrate', 'jews', 'Columbus', 'would', 'celebrate', 'Do', 'RT', 'Um', '_Native_Life', 'Day', 'the', 'you']
# ['aSZTdSXRE7', 't', 'co', 'whitegenocideinsouthafrica', 'http', 'Watch', 'South', 'Africa', 'on', 'RT', 'Benanto', 'Genocide', 'Genocide', 'in']
# ['Kesha', 'twit', 'Free', 'court', 'to', 'fucking', 'the', 'manipulate', 'trying', 'actress', 'to', 'way', 'get', 'fucking', 'her', 'you', 'Fem', 'SJW', 'because', 'a', "she's"]
# ['texas', 'Or', 'russia', 'whitegenocide', 'someplace', 'a', 'homeland', 'ppl', 'in', 'we', 'give', 'elonjames', 'the', 'RT', 'laurelgreen', 'to', 'ask', 'UN', 'the', "Can't"]
# ['ACollegeStudentDay', 'Offend', 'Medievil', 'theatre', 'lit', 'National', 'degree', 'with', 'your', 'gender', 'studies', 'career', 'only', 'your', 'option', 'be', 'may', 'Barista', 'at', 'Starbucks']
# ['Shaming', 'prude', 'bananas', 'Kiwi', 'a', 'I', 'me', 'End', 'call', 'the', 'And', 'if', "don't", 'whore', "I'm", 'sleep', 'labeled', 'if', 'I', 'banana', 'with', 'a', 'Kiwis', 'Yes', 'because', 'All', 'a']
# ['for', 'path', 'Jews', 'clear', 'a', 'Hitler', 'a', 'the', 'to', 'out', 'thing', 'done', 'similar', 'wiping', 'Palestine', 'Netanyahu', 'is']
# ['fuck', 'fight', 'fuck', "Let's", 'fight']
# ['pCSbbeWHm6', 't', 'co', 'TPM', 'http', 'Headline', "'Hungover'", 'Blames', 'For', "'Kill", 'Carlson', 'Editor', 'RT', "Jews'", 'All', 'joshtpm', 'The', 'Tucker']
# ['commemoration', 'so', 'Madinah', 'fasting', 'amp', 'was', 'in', 'city', 'he', 'fasting', 'Moses', 'entering', 'the', 'upon', 'started', 'given', 'reference', 'Jews', 'the', 'saw', 'The', 'prophet', 'pbuh']
# ['h1eOjV6efw', 't', 'https', 'Children', 'co', 'Big', 'Futures', 'Feminist', 'Punishment', 'Corporal', 'Relegalize']
# ['aydlExalS9', "'multiculturalism'", 't', 'and', 'https', 'Islam', 'of', 'co', 'the', 'name', 'in', 'die', 'Brussels', 'Sorry', 'regressive', 'left', 'need', 'Prayersfor', 'to', 'the', 'decided', 'you']
# ['like', 'Jews', 'the', 'money', 'Save']
# ['for', 'fault', "It's", 'Jews', 'exposing', 'it', 'else', 'RT', 'secretkiska', 'sweeneyman18', 'CAIRS', 'the', 'mentality', "someone's", 'blames', 'always']
# ['not', 'are', 'and', 'which', 'do', 'to', 'this', 'of', 'paid', 'are', 'these', 'which', 'people', 'determine', 'to', 'a', 'There', 'to', 'way', 'uberfeminist', 'be', 'needs']
# ['shoegal90', 'Hilgerman', 'REM', 'blacks', '63489', 'Joe', 'kill', 'thought', 'didnt', 'black', 'why', 'they', 'he', 'were', 'he', 'because', 'the', 'Jews', 'killed', 'if', 'REALBROTHER', 'lt', '0003', 'Hitler']
# ['Jews', 'the', 'dominated', 'by', 'and', 'Illuminati', 'The', 'Communism', 'run', 'Freemasonry', 'is', 'owned', 'is', 'Jewish', 'is', 'Jewish']
# ['rr7DJPX6mY', 'https', 't', 'co', 'her', 'ate', 'gator', 'a', 'Hopefully']
# ['w', 't', 'lithuania', 'rapefugees', 'https', 'estonia', 'finland', 'norway', 'co', 'whitegenocide', 'hungary', 'latvia', 'usa', 'Genocider', 'migrants', 'Anti', 'Poland', 'RT']
# ['whitelivesmattermore', 'bean907', 'RT']
# ['bull', 'All', 'gift', 'started', 'woman', 'me', 'get', 'a', 'as', 'a', 'gamergate', 'by', "don't", 'Tim', 'shirt', 'hoaxes', 'misquoted', 'Rape', 'given', 'Hunt', 'bull', 'out', 'cones', 'as', '2', '2', 'gchewie']
# ['ww2', 'they', 'Jews', 'about', 'how', 'their', 'during', 'house', "grandma's", 'the', 'in', 'emotional', 'hid', 'my', 'at', 'story', 'Getting']
# ['gaming', 'time', 'remainers', 'on', 'that', 'hours', 'quality', 'have', 'heckling', 'spent', 'should', 'been', 'fucking', 'Metal', 'Pixel', 'spent', 'I']
# ['XScRI', 'Iaf', 'NF', 't', 'co', 'laid', 'down', 'http', 'weapons', 'Jews', 'their', 'the', 'if', 'VIDEO', 'What']
# ['Torah', 'they', 'Israel', 'with', 'the', 'covenant', 'In', 'to', 'God', 'by', 'live', 'promised', 'has', 'They', 'different', 'are', 'nations', 'a', 'Western', 'like', 'vain', 'be', 'to', 'try', 'The', 'Jews']
# ['Nakba', 'mourning', 'Israel', 'and', 'are', 'expelled', 'Day', 'now', 'got', 'from', 'jews', 'kill', 'the', 'moment', 'Palestinians', 'to', 'tried', 'That']
# ['taught', 'good', 'you', 'jews', 'The', 'look', 'it', 'RT', 'wont', 'Maximus339', 'tho', 'up', 'You']
# ['0nTQltHF', 'RR', 't', 'co', 'http', 'not', 'bullshit', 'or', 'innocent', 'would', 'jews', 'all', 'right', 'if', 'utter', 'the', 'killing', 'be', 'did', 'What', 'he', 'Yeah', 'because', 'then']
# ['eTTwDjvV6J', 't', 'janet_tilch', 'kraff91', 'co', 'morganraff', 'Rockefeller', 'Center', 'http', 'X-mas', 'stole', 'Jews', 'the', 'How']
